# %%
import pandas as pd
import regex as re
import numpy as np
import urllib3
import requests
import sqlite3
from IPython.display import display, clear_output
import json
from datetime import date,datetime
today = date.today().strftime("%Y-%m-%d")
base = 'https://statsapi.web.nhl.com'

# %%
def convertDates(date_val):
    """
    convertCheckDates:
    Description: Checks for actual dates and returns date 'YYYY-MM-DD'.
    If not an actual date will fail and flag an assertion error.
    """
    # accepted date values to convert to string dates
    acc_values = (type(datetime.today()), type(date.today()))
    
    # if acceptable date than return as string date
    if type(date_val) in  acc_values: 
        return date_val.date()
   
    # regular expression to validate string dates
    p = re.compile('\d{4}-\d{1,2}-\d{1,2}')
    m = p.match(date_val)
   
    # if not a correct date than will flag an error
    assert(m), """Date was entered incorrectly should be a date field or string date 'YYYY-MM-DD'"""
    
    return datetime.strptime(date_val, '%Y-%m-%d').date()

# %%
def getNHLGames(start = today, end = today):
    """
    getNHLGames:
    Description: This will pull all NHL games based on the variables pased through. If variables are not 
    passed will defualt to the current date.
    """
    start = convertDates(start)
    end  = convertDates(end)
    # flag if start date is greater than end 
    assert(start <= end), "Start date ({}) needs to be less than the end date ({})".format(start, end)
    
    url = base + '/api/v1/schedule?&startDate={}&endDate={}'.format(start,end)
    try: 
        resp = requests.get(url)

        # just making sure we have a response
        assert(resp.status_code == 200), '''{}: Nothing returned check the link {}'''.format(resp.status_code, url)
   
    except urllib3.exceptions.HTTPError as e:
        print('Well, we tried but, {}'.format(e))
    
    return resp

# %%
def setGamesToDF(data):
    """
    setGamesToDF: 
    Description: Takes the response for the getNHLGames call and converts the data to a pandas data frame.
    """
    games= {}
    for i in data['dates']:
        for ii in i['games']:
            games[ii['gamePk']] = {'link' : ii['link'], 
                          'season' : ii['season'], 
                          'gameDate' : ii['gameDate'], 
                          'gameType': str(ii['gamePk'])[4:6],
                          'awayTeamId' : ii['teams']['away']['team']['id'], 
                          'homeTeamId' : ii['teams']['home']['team']['id']
                         }
    df = pd.DataFrame.from_dict(games, orient = 'index')
    return df

# %%
resp = getNHLGames('2014-10-01')
nhlGames = setGamesToDF(resp.json())
nhlGames.head()
# Out:
#                                          link    season              gameDate  \
# 2014010077  /api/v1/game/2014010077/feed/live  20142015  2014-10-01T23:00:00Z
# 2014010079  /api/v1/game/2014010079/feed/live  20142015  2014-10-01T23:00:00Z
# 2014010081  /api/v1/game/2014010081/feed/live  20142015  2014-10-01T23:30:00Z
# 2014010078  /api/v1/game/2014010078/feed/live  20142015  2014-10-02T00:30:00Z
# 2014010080  /api/v1/game/2014010080/feed/live  20142015  2014-10-02T01:00:00Z
#
#            gameType  awayTeamId  homeTeamId
# 2014010077       01          15           7
# 2014010079       01          12          29
# 2014010081       01           5          17
# 2014010078       01           8          16
# 2014010080       01          53          22

# %%
def pullGameData(link): 
    """
    pullGameData:
    Description: Pulls individual game data from the nhl website and returns the repsonse.
    """
    # regular expression to validate the link
    p = re.compile('/api/v1/game/\d{10}/feed/live')
    m = p.search(link)
    assert(m), """{} passed to the function 'pullGameData' should be '/api/v1/game/[gameid]/feed/live'""".format(link)
    
    # in case the full path is passed through, drop base and add back in
    link = m[0]
    url = base + link
    
    try:
        resp = requests.get(url)
        
        # just making sure we have a response
        assert(resp.status_code == 200), '''{}: Nothing returned check the link {}'''.format(resp.status_code, link)
    
    except urllib3.exceptions.HTTPError as e:
        print('Well, we tried but, {}'.format(e))
    
    return resp

# %%
def gameEventsDictionary(data): 
    """
    gameEventsDictionary:
    Description: Game data is passed through as json for each game, and this function pulls all the events
    from the game passed and passes it back as a dictionary.
    """
    #gameid
    gamePk = str(data['gamePk'])
    gameDict = {}
    
    # liveData is where all the game information is stored
    for gEvent in data['liveData']['plays']['allPlays']:
        
        try:
            _dict_ = {}
            _dict_['event'] = gEvent['result']['event']
            _dict_['period'] = gEvent['about']['period']
            _dict_['periodType'] = gEvent['about']['periodType']
            _dict_['periodTime'] = gEvent['about']['periodTime']
            _dict_['periodTimeRemaining'] : gEvent['about']['periodTimeRemaining']
            _dict_['dateTime'] = gEvent['about']['dateTime']
            
            # tracking the points on each event
            _dict_['home'] = gEvent['about']['goals']['home']
            _dict_['away'] = gEvent['about']['goals']['away']
            _dict_['description'] = gEvent['result']['description']
            
            # x and y coordinates are stored here
            if len(gEvent['coordinates']) > 0:
                # ran into instances where just one coordinate was populated
                for k,v in gEvent['coordinates'].items():
                    _dict_[k] = v
                    
            if 'team' in gEvent.keys():
                _dict_['eventTeam'] = gEvent['team']['id']
            
            if 'players' in gEvent.keys():
                for i in range(len(gEvent['players'])):
                    _dict_['playerid' + str(i+1)] = gEvent['players'][i]['player']['id']
                    _dict_['playerType' + str(i+1)] = gEvent['players'][i]['playerType']

        except:
            # trying to give enough information to know which game event failed
            print('{} - failed at line {}'.format(gamePk, gEvent['about']['eventIdx']))
            
        gameDict[int(gamePk + str( gEvent['about']['eventIdx']))] =_dict_
    return gameDict

# %%
def getEvents(data):
    """
    getEvents:
    This is where all the data is pulled together. The function calls pullGameData, and appends a dictionary
    for each game that was played.
    """
    _dict_={}
    n = len(data) - 1
    ii = 0
    for i in data:
        # update bar used to clear out output and refresh progress
        clear_output(wait=True) 
        
        # calculating percent completed
        print('{} - {} % complete'.format(ii, ii/n * 100))
        
        # calls data based on link for game
        _resp_ = pullGameData(i)
        
        # gameEventsDictionary breaks each game event out line by line
        _dict_.update(gameEventsDictionary(_resp_.json()))
        
        ii += 1 # increment counter for % completed
        
    # create dictionary to return the data
    df = pd.DataFrame.from_dict(_dict_, orient = 'index')
    
    return df

# %%
eventTable = getEvents(nhlGames.link.values)
# Out:
# 8330 - 100.0 % complete

# %%
eventTable.head()
# Out:
#                       event  period periodType periodTime  \
# 20140100770  Game Scheduled       1    REGULAR      00:00
# 20140100771    Period Ready       1    REGULAR      00:00
# 20140100772    Period Start       1    REGULAR      00:00
# 20140100773         Faceoff       1    REGULAR      00:00
# 20140100774             Hit       1    REGULAR      00:15
#
#                          dateTime  home  away  \
# 20140100770  2014-10-01T21:15:40Z     0     0
# 20140100771  2014-10-01T22:53:59Z     0     0
# 20140100772  2014-10-01T23:07:19Z     0     0
# 20140100773  2014-10-01T23:07:19Z     0     0
# 20140100774  2014-10-01T23:08:22Z     0     0
#
#                                                   description     x     y  \
# 20140100770                                    Game Scheduled   NaN   NaN
# 20140100771                                      Period Ready   NaN   NaN
# 20140100772                                      Period Start   NaN   NaN
# 20140100773  Tyler Ennis faceoff won against Andre Burakovsky   0.0   0.0
# 20140100774                      Brooks Laich hit Tyler Myers -74.0 -40.0
#
#              eventTeam  playerid1 playerType1  playerid2 playerType2  \
# 20140100770        NaN        NaN         NaN        NaN         NaN
# 20140100771        NaN        NaN         NaN        NaN         NaN
# 20140100772        NaN        NaN         NaN        NaN         NaN
# 20140100773        7.0  8474589.0      Winner  8477444.0       Loser
# 20140100774       15.0  8469639.0      Hitter  8474574.0      Hittee
#
#              playerid3 playerType3  playerid4 playerType4
# 20140100770        NaN         NaN        NaN         NaN
# 20140100771        NaN         NaN        NaN         NaN
# 20140100772        NaN         NaN        NaN         NaN
# 20140100773        NaN         NaN        NaN         NaN
# 20140100774        NaN         NaN        NaN         NaN

# %%
eventTable.res
# Out:
# Index(['event', 'period', 'periodType', 'periodTime', 'dateTime', 'home',
#        'away', 'description', 'x', 'y', 'eventTeam', 'playerid1',
#        'playerType1', 'playerid2', 'playerType2', 'playerid3', 'playerType3',
#        'playerid4', 'playerType4'],
#       dtype='object')

# %%
# storing data in sql
query = """ 
            CREATE TABLE DIM_EVENT_TABLE
            (   id INTEGER,
                event VARCHAR(50),
                period INTEGER,
                periodType VARCHAR(50),
                periodTime VARCHAR(10),
                dateTime VARCHAR(30),
                home INTEGER,
                away INTEGER,
                description VARCHAR(200),
                x INTEGER,
                y INTEGER,
                eventTeam INTEGER,
                playerid1 INTEGER,
                playerType1 VARCHAR(50),
                playerid2 INTEGER,
                playerType2 VARCHAR(50),
                playerid3 INTEGER,
                playerType3 VARCHAR(50),
                playerid4 INTEGER,
                playerType4 VARCHAR(50)
            );"""

# %%
# now we need to create our database or place to store the table
con = sqlite3.connect('dsc_550_project.sqlite') 
# commit, keeps the entire transaction, else it will be rolled back once we log out
con.execute(query)
# excecute the create table statement so we have a table set up
con.commit()

# %%
#insert statement, '?' are like the placeholders for the variables
stmt = "INSERT INTO DIM_EVENT_TABLE VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)"
# normally in sql you would have the insert statemnt above and then the data below
# doing it like this tells sqlite to insert and then we have the values after the comma
con.executemany(stmt, eventTable.reset_index().values.tolist())
con.commit()

# %%
# creating sel * to see the data
cursor = con.execute('Select * from DIM_EVENT_TABLE')
rows = cursor.fetchall()
rows
# Out:
# [(20140100770,
#   'Game Scheduled',
#   1,
#   'REGULAR',
#   '00:00',
#   '2014-10-01T21:15:40Z',
#   0,
#   0,
#   'Game Scheduled',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (20140100771,
#   'Period Ready',
#   1,
#   'REGULAR',
#   '00:00',
#   '2014-10-01T22:53:59Z',
#   0,
#   0,
#   'Period Ready',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (20140100772,
#   'Period Start',
#   1,
#   'REGULAR',
#   '00:00',
#   '2014-10-01T23:07:19Z',
#   0,
#   0,
#   'Period Start',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (20140100773,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '00:00',
#   '2014-10-01T23:07:19Z',
#   0,
#   0,
#   'Tyler Ennis faceoff won against Andre Burakovsky',
#   0,
#   0,
#   7,
#   8474589,
#   'Winner',
#   8477444,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (20140100774,
#   'Hit',
#   1,
#   'REGULAR',
#   '00:15',
#   '2014-10-01T23:08:22Z',
#   0,
#   0,
#   'Brooks Laich hit Tyler Myers',
#   -74,
#   -40,
#   15,
#   8469639,
#   'Hitter',
#   8474574,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (20140100775,
#   'Shot',
#   1,
#   'REGULAR',
#   '00:17',
#   '2014-10-01T23:08:24Z',
#   0,
#   0,
#   'Tyler Ennis Snap Shot saved by Braden Holtby',
#   55,
#   27,
#   7,
#   8474589,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (20140100776,
#   'Shot',
#   1,
#   'REGULAR',
#   '00:24',
#   '2014-10-01T23:08:30Z',
#   0,
#   0,
#   'Tyler Myers Wrist Shot saved by Braden Holtby',
#   35,
#   -10,
#   7,
#   8474574,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (20140100777,
#   'Hit',
#   1,
#   'REGULAR',
#   '00:50',
#   '2014-10-01T23:08:56Z',
#   0,
#   0,
#   'Jason Chimera hit Drew Stafford',
#   -74,
#   -41,
#   15,
#   8466251,
#   'Hitter',
#   8471226,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (20140100778,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '01:10',
#   '2014-10-01T23:09:18Z',
#   0,
#   0,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (20140100779,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '01:10',
#   '2014-10-01T23:09:34Z',
#   0,
#   0,
#   'Marcus Johansson faceoff won against Sam Reinhart',
#   69,
#   22,
#   15,
#   8475149,
#   'Winner',
#   8477933,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007710,
#   'Missed Shot',
#   1,
#   'REGULAR',
#   '01:29',
#   '2014-10-01T23:10:02Z',
#   0,
#   0,
#   'Chris Stewart - Over Net',
#   65,
#   -9,
#   7,
#   8473485,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007711,
#   'Shot',
#   1,
#   'REGULAR',
#   '02:02',
#   '2014-10-01T23:10:35Z',
#   0,
#   0,
#   'Casey Wellman Snap Shot saved by Jhonas Enroth',
#   -46,
#   -18,
#   15,
#   8475602,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007712,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '02:06',
#   '2014-10-01T23:10:39Z',
#   0,
#   0,
#   'Net Off',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007713,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '02:06',
#   '2014-10-01T23:10:55Z',
#   0,
#   0,
#   'Kris Newbury faceoff won against Zemgus Girgensons',
#   -69,
#   -22,
#   15,
#   8470232,
#   'Winner',
#   8476878,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007714,
#   'Takeaway',
#   1,
#   'REGULAR',
#   '02:13',
#   '2014-10-01T23:11:17Z',
#   0,
#   0,
#   'Takeaway by Zac Dalpe',
#   -60,
#   -25,
#   7,
#   8474610,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007715,
#   'Missed Shot',
#   1,
#   'REGULAR',
#   '02:24',
#   '2014-10-01T23:11:28Z',
#   0,
#   0,
#   'Brian Flynn - Wide of Net',
#   72,
#   3,
#   7,
#   8476808,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007716,
#   'Hit',
#   1,
#   'REGULAR',
#   '02:27',
#   '2014-10-01T23:11:31Z',
#   0,
#   0,
#   'Kris Newbury hit Zemgus Girgensons',
#   91,
#   38,
#   15,
#   8470232,
#   'Hitter',
#   8476878,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (201401007717,
#   'Shot',
#   1,
#   'REGULAR',
#   '02:30',
#   '2014-10-01T23:11:34Z',
#   0,
#   0,
#   'Tyler Myers Wrist Shot saved by Braden Holtby',
#   35,
#   -28,
#   7,
#   8474574,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007718,
#   'Missed Shot',
#   1,
#   'REGULAR',
#   '02:35',
#   '2014-10-01T23:11:39Z',
#   0,
#   0,
#   'Zac Dalpe - Wide of Net',
#   63,
#   -14,
#   7,
#   8474610,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007719,
#   'Shot',
#   1,
#   'REGULAR',
#   '02:52',
#   '2014-10-01T23:12:07Z',
#   0,
#   0,
#   'Tyler Ennis Backhand saved by Braden Holtby',
#   70,
#   -29,
#   7,
#   8474589,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007720,
#   'Goal',
#   1,
#   'REGULAR',
#   '02:54',
#   '2014-10-01T23:12:00Z',
#   1,
#   0,
#   'Matt Moulson (1) Wrist Shot, assists: Tyler Ennis (2), Brian Gionta (1)',
#   81,
#   -1,
#   7,
#   8470852,
#   'Scorer',
#   8474589,
#   'Assist',
#   8467407,
#   'Assist',
#   8474651,
#   'Goalie'),
#  (201401007721,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '02:54',
#   '2014-10-01T23:12:32Z',
#   1,
#   0,
#   'Tyler Ennis faceoff won against Evgeny Kuznetsov',
#   0,
#   0,
#   7,
#   8474589,
#   'Winner',
#   8475744,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007722,
#   'Penalty',
#   1,
#   'REGULAR',
#   '03:13',
#   '2014-10-01T23:13:04Z',
#   1,
#   0,
#   'Tyler Ennis Slashing against Joel Ward',
#   -13,
#   -35,
#   7,
#   8474589,
#   'PenaltyOn',
#   8468208,
#   'DrewBy',
#   None,
#   None,
#   None,
#   None),
#  (201401007723,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '03:13',
#   '2014-10-01T23:13:21Z',
#   1,
#   0,
#   'Marcus Johansson faceoff won against Drew Stafford',
#   -69,
#   -22,
#   15,
#   8475149,
#   'Winner',
#   8471226,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007724,
#   'Takeaway',
#   1,
#   'REGULAR',
#   '03:46',
#   '2014-10-01T23:14:04Z',
#   1,
#   0,
#   'Takeaway by Josh Gorges',
#   -93,
#   21,
#   7,
#   8470324,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007725,
#   'Hit',
#   1,
#   'REGULAR',
#   '05:01',
#   '2014-10-01T23:15:18Z',
#   1,
#   0,
#   'Josh Gorges hit Garrett Mitchell',
#   -74,
#   40,
#   7,
#   8470324,
#   'Hitter',
#   8475291,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (201401007726,
#   'Penalty',
#   1,
#   'REGULAR',
#   '05:27',
#   '2014-10-01T23:15:58Z',
#   1,
#   0,
#   'Kris Newbury Holding against Brian Gionta',
#   97,
#   23,
#   15,
#   8470232,
#   'PenaltyOn',
#   8467407,
#   'DrewBy',
#   None,
#   None,
#   None,
#   None),
#  (201401007727,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '05:27',
#   '2014-10-01T23:16:09Z',
#   1,
#   0,
#   'Joel Ward faceoff won against Mikhail Grigorenko',
#   69,
#   22,
#   15,
#   8468208,
#   'Winner',
#   8476888,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007728,
#   'Goal',
#   1,
#   'REGULAR',
#   '06:01',
#   '2014-10-01T23:16:52Z',
#   2,
#   0,
#   'Drew Stafford (2) Slap Shot, assists: Cody Hodgson (2), Nikita Zadorov (1)',
#   54,
#   6,
#   7,
#   8471226,
#   'Scorer',
#   8474570,
#   'Assist',
#   8477507,
#   'Assist',
#   8474651,
#   'Goalie'),
#  (201401007729,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '06:01',
#   '2014-10-01T23:17:20Z',
#   2,
#   0,
#   'Andre Burakovsky faceoff won against Sam Reinhart',
#   0,
#   0,
#   15,
#   8477444,
#   'Winner',
#   8477933,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007730,
#   'Hit',
#   1,
#   'REGULAR',
#   '06:28',
#   '2014-10-01T23:17:52Z',
#   2,
#   0,
#   'Andre Burakovsky hit Marcus Foligno',
#   0,
#   -30,
#   15,
#   8477444,
#   'Hitter',
#   8475220,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (201401007731,
#   'Blocked Shot',
#   1,
#   'REGULAR',
#   '06:42',
#   '2014-10-01T23:18:06Z',
#   2,
#   0,
#   'John Erskine blocked shot from Jake McCabe',
#   60,
#   -4,
#   15,
#   8467365,
#   'Blocker',
#   8476931,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (201401007732,
#   'Hit',
#   1,
#   'REGULAR',
#   '06:55',
#   '2014-10-01T23:18:18Z',
#   2,
#   0,
#   'Marcus Foligno hit Brooks Laich',
#   85,
#   -41,
#   7,
#   8475220,
#   'Hitter',
#   8469639,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (201401007733,
#   'Blocked Shot',
#   1,
#   'REGULAR',
#   '06:56',
#   '2014-10-01T23:18:20Z',
#   2,
#   0,
#   'John Erskine blocked shot from Jake McCabe',
#   60,
#   -8,
#   15,
#   8467365,
#   'Blocker',
#   8476931,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (201401007734,
#   'Shot',
#   1,
#   'REGULAR',
#   '07:11',
#   '2014-10-01T23:18:35Z',
#   2,
#   0,
#   'Zac Dalpe Wrist Shot saved by Braden Holtby',
#   48,
#   -2,
#   7,
#   8474610,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007735,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '07:28',
#   '2014-10-01T23:18:54Z',
#   2,
#   0,
#   'Icing',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007736,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '07:28',
#   '2014-10-01T23:20:08Z',
#   2,
#   0,
#   'Marcus Johansson faceoff won against Brian Gionta',
#   69,
#   -22,
#   15,
#   8475149,
#   'Winner',
#   8467407,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007737,
#   'Shot',
#   1,
#   'REGULAR',
#   '07:52',
#   '2014-10-01T23:20:34Z',
#   2,
#   0,
#   'Brian Gionta Backhand saved by Braden Holtby',
#   77,
#   7,
#   7,
#   8467407,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007738,
#   'Shot',
#   1,
#   'REGULAR',
#   '08:44',
#   '2014-10-01T23:21:26Z',
#   2,
#   0,
#   'Drew Stafford Wrist Shot saved by Braden Holtby',
#   56,
#   -21,
#   7,
#   8471226,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007739,
#   'Blocked Shot',
#   1,
#   'REGULAR',
#   '08:53',
#   '2014-10-01T23:21:35Z',
#   2,
#   0,
#   'Andre Benoit blocked shot from Jason Chimera',
#   -72,
#   10,
#   7,
#   8470378,
#   'Blocker',
#   8466251,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (201401007740,
#   'Shot',
#   1,
#   'REGULAR',
#   '10:06',
#   '2014-10-01T23:22:48Z',
#   2,
#   0,
#   'Patrick Wey Slap Shot saved by Jhonas Enroth',
#   -33,
#   20,
#   15,
#   8475275,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007741,
#   'Shot',
#   1,
#   'REGULAR',
#   '11:16',
#   '2014-10-01T23:23:59Z',
#   2,
#   0,
#   'Joel Ward Slap Shot saved by Jhonas Enroth',
#   -42,
#   8,
#   15,
#   8468208,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007742,
#   'Shot',
#   1,
#   'REGULAR',
#   '11:24',
#   '2014-10-01T23:24:06Z',
#   2,
#   0,
#   'Jack Hillen Wrap-around saved by Jhonas Enroth',
#   -88,
#   8,
#   15,
#   8474519,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007743,
#   'Hit',
#   1,
#   'REGULAR',
#   '11:45',
#   '2014-10-01T23:24:27Z',
#   2,
#   0,
#   'Dane Byers hit Jake McCabe',
#   -98,
#   18,
#   15,
#   8471261,
#   'Hitter',
#   8476931,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (201401007744,
#   'Giveaway',
#   1,
#   'REGULAR',
#   '12:07',
#   '2014-10-01T23:24:49Z',
#   2,
#   0,
#   'Giveaway by Dane Byers',
#   -48,
#   -2,
#   15,
#   8471261,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007745,
#   'Missed Shot',
#   1,
#   'REGULAR',
#   '12:12',
#   '2014-10-01T23:24:54Z',
#   2,
#   0,
#   'Troy Brouwer - Over Net',
#   -56,
#   -23,
#   15,
#   8471426,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007746,
#   'Missed Shot',
#   1,
#   'REGULAR',
#   '12:21',
#   '2014-10-01T23:25:03Z',
#   2,
#   0,
#   'Andre Burakovsky - Goalpost',
#   -54,
#   3,
#   15,
#   8477444,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007747,
#   'Shot',
#   1,
#   'REGULAR',
#   '12:35',
#   '2014-10-01T23:25:20Z',
#   2,
#   0,
#   'Andre Burakovsky Wrist Shot saved by Jhonas Enroth',
#   -87,
#   -16,
#   15,
#   8477444,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007748,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '12:38',
#   '2014-10-01T23:25:23Z',
#   2,
#   0,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007749,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '12:38',
#   '2014-10-01T23:27:12Z',
#   2,
#   0,
#   'Mikhail Grigorenko faceoff won against Marcus Johansson',
#   -69,
#   22,
#   7,
#   8476888,
#   'Winner',
#   8475149,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007750,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '12:55',
#   '2014-10-01T23:28:01Z',
#   2,
#   0,
#   'Icing',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007751,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '12:55',
#   '2014-10-01T23:28:01Z',
#   2,
#   0,
#   'Mikhail Grigorenko faceoff won against Evgeny Kuznetsov',
#   -69,
#   22,
#   7,
#   8476888,
#   'Winner',
#   8475744,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007752,
#   'Hit',
#   1,
#   'REGULAR',
#   '13:08',
#   '2014-10-01T23:28:39Z',
#   2,
#   0,
#   'Mikhail Grigorenko hit Patrick Wey',
#   98,
#   -1,
#   7,
#   8476888,
#   'Hitter',
#   8475275,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (201401007753,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '13:15',
#   '2014-10-01T23:28:48Z',
#   2,
#   0,
#   'Icing',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007754,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '13:15',
#   '2014-10-01T23:28:55Z',
#   2,
#   0,
#   'Evgeny Kuznetsov faceoff won against Sam Reinhart',
#   69,
#   22,
#   15,
#   8475744,
#   'Winner',
#   8477933,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007755,
#   'Shot',
#   1,
#   'REGULAR',
#   '14:01',
#   '2014-10-01T23:29:54Z',
#   2,
#   0,
#   'Dane Byers Wrist Shot saved by Jhonas Enroth',
#   -58,
#   -14,
#   15,
#   8471261,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007756,
#   'Shot',
#   1,
#   'REGULAR',
#   '14:31',
#   '2014-10-01T23:30:24Z',
#   2,
#   0,
#   'Zac Dalpe Wrist Shot saved by Braden Holtby',
#   67,
#   -26,
#   7,
#   8474610,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007757,
#   'Hit',
#   1,
#   'REGULAR',
#   '14:34',
#   '2014-10-01T23:30:27Z',
#   2,
#   0,
#   'Zac Dalpe hit John Erskine',
#   98,
#   -7,
#   7,
#   8474610,
#   'Hitter',
#   8467365,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (201401007758,
#   'Takeaway',
#   1,
#   'REGULAR',
#   '14:53',
#   '2014-10-01T23:30:46Z',
#   2,
#   0,
#   'Takeaway by Josh Gorges',
#   -58,
#   -34,
#   7,
#   8470324,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007759,
#   'Shot',
#   1,
#   'REGULAR',
#   '14:59',
#   '2014-10-01T23:30:52Z',
#   2,
#   0,
#   'Josh Gorges Slap Shot saved by Braden Holtby',
#   31,
#   20,
#   7,
#   8470324,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007760,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '15:00',
#   '2014-10-01T23:30:53Z',
#   2,
#   0,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007761,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '15:00',
#   '2014-10-01T23:32:32Z',
#   2,
#   0,
#   'Tyler Ennis faceoff won against Andre Burakovsky',
#   69,
#   22,
#   7,
#   8474589,
#   'Winner',
#   8477444,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007762,
#   'Shot',
#   1,
#   'REGULAR',
#   '15:15',
#   '2014-10-01T23:33:15Z',
#   2,
#   0,
#   'Tyler Ennis Wrist Shot saved by Braden Holtby',
#   86,
#   -7,
#   7,
#   8474589,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007763,
#   'Hit',
#   1,
#   'REGULAR',
#   '15:26',
#   '2014-10-01T23:33:25Z',
#   2,
#   0,
#   'Brooks Laich hit Nikita Zadorov',
#   -88,
#   -40,
#   15,
#   8469639,
#   'Hitter',
#   8477507,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (201401007764,
#   'Shot',
#   1,
#   'REGULAR',
#   '15:47',
#   '2014-10-01T23:33:46Z',
#   2,
#   0,
#   'Joel Ward Slap Shot saved by Jhonas Enroth',
#   -42,
#   25,
#   15,
#   8468208,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007765,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '15:49',
#   '2014-10-01T23:33:50Z',
#   2,
#   0,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007766,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '15:49',
#   '2014-10-01T23:34:04Z',
#   2,
#   0,
#   'Joel Ward faceoff won against Mikhail Grigorenko',
#   -69,
#   22,
#   15,
#   8468208,
#   'Winner',
#   8476888,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007767,
#   'Hit',
#   1,
#   'REGULAR',
#   '16:04',
#   '2014-10-01T23:34:28Z',
#   2,
#   0,
#   'Joel Ward hit Jake McCabe',
#   -74,
#   42,
#   15,
#   8468208,
#   'Hitter',
#   8476931,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (201401007768,
#   'Blocked Shot',
#   1,
#   'REGULAR',
#   '16:32',
#   '2014-10-01T23:34:56Z',
#   2,
#   0,
#   'Tyson Strachan blocked shot from Evgeny Kuznetsov',
#   -69,
#   -25,
#   7,
#   8470729,
#   'Blocker',
#   8475744,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (201401007769,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '16:33',
#   '2014-10-01T23:35:12Z',
#   2,
#   0,
#   'Puck in Crowd',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007770,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '16:33',
#   '2014-10-01T23:36:41Z',
#   2,
#   0,
#   'Sam Reinhart faceoff won against Marcus Johansson',
#   -69,
#   -22,
#   7,
#   8477933,
#   'Winner',
#   8475149,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007771,
#   'Blocked Shot',
#   1,
#   'REGULAR',
#   '16:40',
#   '2014-10-01T23:37:11Z',
#   2,
#   0,
#   'Sam Reinhart blocked shot from Marcus Johansson',
#   -86,
#   15,
#   7,
#   8477933,
#   'Blocker',
#   8475149,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (201401007772,
#   'Blocked Shot',
#   1,
#   'REGULAR',
#   '17:18',
#   '2014-10-01T23:37:48Z',
#   2,
#   0,
#   'Karl Alzner blocked shot from Marcus Foligno',
#   76,
#   8,
#   15,
#   8473991,
#   'Blocker',
#   8475220,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (201401007773,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '17:36',
#   '2014-10-01T23:38:10Z',
#   2,
#   0,
#   'Puck in Benches',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007774,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '17:36',
#   '2014-10-01T23:38:30Z',
#   2,
#   0,
#   'Zemgus Girgensons faceoff won against Kris Newbury',
#   0,
#   0,
#   7,
#   8476878,
#   'Winner',
#   8470232,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007775,
#   'Missed Shot',
#   1,
#   'REGULAR',
#   '17:59',
#   '2014-10-01T23:38:54Z',
#   2,
#   0,
#   'Garrett Mitchell - Over Net',
#   19,
#   3,
#   15,
#   8475291,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007776,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '18:01',
#   '2014-10-01T23:38:56Z',
#   2,
#   0,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007777,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '18:01',
#   '2014-10-01T23:39:16Z',
#   2,
#   0,
#   'Tyler Ennis faceoff won against Andre Burakovsky',
#   -69,
#   22,
#   7,
#   8474589,
#   'Winner',
#   8477444,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007778,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '18:13',
#   '2014-10-01T23:39:44Z',
#   2,
#   0,
#   'Icing',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007779,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '18:13',
#   '2014-10-01T23:39:50Z',
#   2,
#   0,
#   'Brooks Laich faceoff won against Tyler Ennis',
#   -69,
#   -22,
#   15,
#   8469639,
#   'Winner',
#   8474589,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007780,
#   'Shot',
#   1,
#   'REGULAR',
#   '18:20',
#   '2014-10-01T23:40:14Z',
#   2,
#   0,
#   'Andre Burakovsky Wrist Shot saved by Jhonas Enroth',
#   -64,
#   30,
#   15,
#   8477444,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007781,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '18:27',
#   '2014-10-01T23:40:24Z',
#   2,
#   0,
#   'Icing',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007782,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '18:27',
#   '2014-10-01T23:40:28Z',
#   2,
#   0,
#   'Tyler Ennis faceoff won against Evgeny Kuznetsov',
#   -69,
#   22,
#   7,
#   8474589,
#   'Winner',
#   8475744,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007783,
#   'Shot',
#   1,
#   'REGULAR',
#   '18:37',
#   '2014-10-01T23:40:57Z',
#   2,
#   0,
#   'Brian Gionta Snap Shot saved by Braden Holtby',
#   69,
#   -2,
#   7,
#   8467407,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007784,
#   'Goal',
#   1,
#   'REGULAR',
#   '18:38',
#   '2014-10-01T23:41:04Z',
#   3,
#   0,
#   'Tyler Ennis (2) Snap Shot, assists: Brian Gionta (2), Tyler Myers (2)',
#   79,
#   3,
#   7,
#   8474589,
#   'Scorer',
#   8467407,
#   'Assist',
#   8474574,
#   'Assist',
#   8474651,
#   'Goalie'),
#  (201401007785,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '18:38',
#   '2014-10-01T23:41:32Z',
#   3,
#   0,
#   'Marcus Johansson faceoff won against Mikhail Grigorenko',
#   0,
#   0,
#   15,
#   8475149,
#   'Winner',
#   8476888,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007786,
#   'Hit',
#   1,
#   'REGULAR',
#   '19:21',
#   '2014-10-01T23:42:18Z',
#   3,
#   0,
#   'Casey Wellman hit Nikita Zadorov',
#   -97,
#   27,
#   15,
#   8475602,
#   'Hitter',
#   8477507,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (201401007787,
#   'Shot',
#   1,
#   'REGULAR',
#   '19:21',
#   '2014-10-01T23:42:20Z',
#   3,
#   0,
#   'Marcus Johansson Tip-In saved by Jhonas Enroth',
#   -71,
#   5,
#   15,
#   8475149,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007788,
#   'Stoppage',
#   1,
#   'REGULAR',
#   '19:22',
#   '2014-10-01T23:42:24Z',
#   3,
#   0,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007789,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '19:22',
#   '2014-10-01T23:42:36Z',
#   3,
#   0,
#   'Kris Newbury faceoff won against Sam Reinhart',
#   -69,
#   22,
#   15,
#   8470232,
#   'Winner',
#   8477933,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007790,
#   'Penalty',
#   1,
#   'REGULAR',
#   '19:33',
#   '2014-10-01T23:43:46Z',
#   3,
#   0,
#   'Dane Byers Fighting against Chris Stewart',
#   -34,
#   7,
#   15,
#   8471261,
#   'PenaltyOn',
#   8473485,
#   'DrewBy',
#   None,
#   None,
#   None,
#   None),
#  (201401007791,
#   'Penalty',
#   1,
#   'REGULAR',
#   '19:33',
#   '2014-10-01T23:44:02Z',
#   3,
#   0,
#   'Chris Stewart Fighting against Dane Byers',
#   -35,
#   6,
#   7,
#   8473485,
#   'PenaltyOn',
#   8471261,
#   'DrewBy',
#   None,
#   None,
#   None,
#   None),
#  (201401007792,
#   'Penalty',
#   1,
#   'REGULAR',
#   '19:33',
#   '2014-10-01T23:44:12Z',
#   3,
#   0,
#   'Dane Byers Roughing against Chris Stewart served by Garrett Mitchell',
#   -32,
#   7,
#   15,
#   8471261,
#   'PenaltyOn',
#   8473485,
#   'DrewBy',
#   8475291,
#   'ServedBy',
#   None,
#   None),
#  (201401007793,
#   'Faceoff',
#   1,
#   'REGULAR',
#   '19:33',
#   '2014-10-01T23:44:46Z',
#   3,
#   0,
#   'Tyler Ennis faceoff won against Troy Brouwer',
#   69,
#   22,
#   7,
#   8474589,
#   'Winner',
#   8471426,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (201401007794,
#   'Shot',
#   1,
#   'REGULAR',
#   '19:46',
#   '2014-10-01T23:45:02Z',
#   3,
#   0,
#   'Brian Gionta Wrist Shot saved by Braden Holtby',
#   81,
#   3,
#   7,
#   8467407,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (201401007795,
#   'Missed Shot',
#   1,
#   'REGULAR',
#   '19:59',
#   '2014-10-01T23:45:18Z',
#   3,
#   0,
#   'Brooks Laich - Wide of Net',
#   -87,
#   20,
#   15,
#   8469639,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007796,
#   'Period End',
#   1,
#   'REGULAR',
#   '20:00',
#   '2014-10-01T23:45:37Z',
#   3,
#   0,
#   'End of 1st Period',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007797,
#   'Period Official',
#   1,
#   'REGULAR',
#   '20:00',
#   '2014-10-01T23:45:40Z',
#   3,
#   0,
#   'Period Official',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007798,
#   'Period Ready',
#   2,
#   'REGULAR',
#   '00:00',
#   '2014-10-02T00:03:19Z',
#   3,
#   0,
#   'Period Ready',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (201401007799,
#   'Period Start',
#   2,
#   'REGULAR',
#   '00:00',
#   '2014-10-02T00:04:10Z',
#   3,
#   0,
#   'Period Start',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077100,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '00:00',
#   '2014-10-02T00:04:16Z',
#   3,
#   0,
#   'Brooks Laich faceoff won against Tyler Ennis',
#   0,
#   0,
#   15,
#   8469639,
#   'Winner',
#   8474589,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077101,
#   'Missed Shot',
#   2,
#   'REGULAR',
#   '00:12',
#   '2014-10-02T00:04:35Z',
#   3,
#   0,
#   'Brooks Laich - Wide of Net',
#   32,
#   1,
#   15,
#   8469639,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077102,
#   'Blocked Shot',
#   2,
#   'REGULAR',
#   '01:29',
#   '2014-10-02T00:05:53Z',
#   3,
#   0,
#   'Karl Alzner blocked shot from Nikita Zadorov',
#   -55,
#   20,
#   15,
#   8473991,
#   'Blocker',
#   8477507,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (2014010077103,
#   'Hit',
#   2,
#   'REGULAR',
#   '01:38',
#   '2014-10-02T00:06:01Z',
#   3,
#   0,
#   'Nikita Zadorov hit Chris Conner',
#   18,
#   40,
#   7,
#   8477507,
#   'Hitter',
#   8472368,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077104,
#   'Shot',
#   2,
#   'REGULAR',
#   '01:48',
#   '2014-10-02T00:06:12Z',
#   3,
#   0,
#   'Zac Dalpe Snap Shot saved by Braden Holtby',
#   -81,
#   5,
#   7,
#   8474610,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077105,
#   'Takeaway',
#   2,
#   'REGULAR',
#   '02:12',
#   '2014-10-02T00:06:36Z',
#   3,
#   0,
#   'Takeaway by Marcus Foligno',
#   19,
#   -37,
#   7,
#   8475220,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077106,
#   'Hit',
#   2,
#   'REGULAR',
#   '02:17',
#   '2014-10-02T00:06:41Z',
#   3,
#   0,
#   'Brooks Laich hit Marcus Foligno',
#   18,
#   -40,
#   15,
#   8469639,
#   'Hitter',
#   8475220,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077107,
#   'Shot',
#   2,
#   'REGULAR',
#   '02:47',
#   '2014-10-02T00:07:13Z',
#   3,
#   0,
#   'Jack Hillen Wrist Shot saved by Jhonas Enroth',
#   81,
#   38,
#   15,
#   8474519,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077108,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '02:50',
#   '2014-10-02T00:07:16Z',
#   3,
#   0,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077109,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '02:50',
#   '2014-10-02T00:07:51Z',
#   3,
#   0,
#   'Evgeny Kuznetsov faceoff won against Zemgus Girgensons',
#   69,
#   22,
#   15,
#   8475744,
#   'Winner',
#   8476878,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077110,
#   'Shot',
#   2,
#   'REGULAR',
#   '03:02',
#   '2014-10-02T00:08:18Z',
#   3,
#   0,
#   'Brian Flynn Wrist Shot saved by Braden Holtby',
#   -48,
#   -35,
#   7,
#   8476808,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077111,
#   'Takeaway',
#   2,
#   'REGULAR',
#   '03:57',
#   '2014-10-02T00:09:15Z',
#   3,
#   0,
#   'Takeaway by Tyler Ennis',
#   -58,
#   11,
#   7,
#   8474589,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077112,
#   'Goal',
#   2,
#   'REGULAR',
#   '04:00',
#   '2014-10-02T00:09:18Z',
#   4,
#   0,
#   'Matt Moulson (2) Wrist Shot, assists: Tyler Ennis (3)',
#   -54,
#   15,
#   7,
#   8470852,
#   'Scorer',
#   8474589,
#   'Assist',
#   8474651,
#   'Goalie',
#   None,
#   None),
#  (2014010077113,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '04:00',
#   '2014-10-02T00:09:51Z',
#   4,
#   0,
#   'Tyler Ennis faceoff won against Andre Burakovsky',
#   0,
#   0,
#   7,
#   8474589,
#   'Winner',
#   8477444,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077114,
#   'Missed Shot',
#   2,
#   'REGULAR',
#   '04:27',
#   '2014-10-02T00:10:26Z',
#   4,
#   0,
#   'Brian Gionta - Wide of Net',
#   -64,
#   -17,
#   7,
#   8467407,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077115,
#   'Hit',
#   2,
#   'REGULAR',
#   '05:13',
#   '2014-10-02T00:11:12Z',
#   4,
#   0,
#   'Marcus Johansson hit Jake McCabe',
#   98,
#   -21,
#   15,
#   8475149,
#   'Hitter',
#   8476931,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077116,
#   'Giveaway',
#   2,
#   'REGULAR',
#   '05:40',
#   '2014-10-02T00:11:47Z',
#   4,
#   0,
#   'Giveaway by Patrick Wey',
#   -64,
#   -37,
#   15,
#   8475275,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077117,
#   'Shot',
#   2,
#   'REGULAR',
#   '05:44',
#   '2014-10-02T00:11:43Z',
#   4,
#   0,
#   'Drew Stafford Wrist Shot saved by Braden Holtby',
#   -51,
#   7,
#   7,
#   8471226,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077118,
#   'Shot',
#   2,
#   'REGULAR',
#   '05:48',
#   '2014-10-02T00:11:49Z',
#   4,
#   0,
#   'Drew Stafford Wrist Shot saved by Braden Holtby',
#   -67,
#   8,
#   7,
#   8471226,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077119,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '05:49',
#   '2014-10-02T00:12:15Z',
#   4,
#   0,
#   'Sam Reinhart faceoff won against Evgeny Kuznetsov',
#   -69,
#   22,
#   7,
#   8477933,
#   'Winner',
#   8475744,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077120,
#   'Shot',
#   2,
#   'REGULAR',
#   '05:54',
#   '2014-10-02T00:12:26Z',
#   4,
#   0,
#   'Josh Gorges Wrist Shot saved by Braden Holtby',
#   -75,
#   -35,
#   7,
#   8470324,
#   'Shooter',
#   8474651,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077121,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '05:55',
#   '2014-10-02T00:12:29Z',
#   4,
#   0,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077122,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '05:55',
#   '2014-10-02T00:12:39Z',
#   4,
#   0,
#   'Evgeny Kuznetsov faceoff won against Sam Reinhart',
#   -69,
#   -22,
#   15,
#   8475744,
#   'Winner',
#   8477933,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077123,
#   'Hit',
#   2,
#   'REGULAR',
#   '06:00',
#   '2014-10-02T00:12:51Z',
#   4,
#   0,
#   'Chris Stewart hit Karl Alzner',
#   -97,
#   29,
#   7,
#   8473485,
#   'Hitter',
#   8473991,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077124,
#   'Penalty',
#   2,
#   'REGULAR',
#   '06:46',
#   '2014-10-02T00:13:45Z',
#   4,
#   0,
#   'Tyler Myers Interference against Kris Newbury',
#   44,
#   -37,
#   7,
#   8474574,
#   'PenaltyOn',
#   8470232,
#   'DrewBy',
#   None,
#   None,
#   None,
#   None),
#  (2014010077125,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '06:46',
#   '2014-10-02T00:14:10Z',
#   4,
#   0,
#   'TV timeout',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077126,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '06:46',
#   '2014-10-02T00:15:32Z',
#   4,
#   0,
#   'Joel Ward faceoff won against Zemgus Girgensons',
#   69,
#   -22,
#   15,
#   8468208,
#   'Winner',
#   8476878,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077127,
#   'Missed Shot',
#   2,
#   'REGULAR',
#   '06:57',
#   '2014-10-02T00:16:00Z',
#   4,
#   0,
#   'Troy Brouwer - Wide of Net',
#   79,
#   23,
#   15,
#   8471426,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077128,
#   'Blocked Shot',
#   2,
#   'REGULAR',
#   '07:32',
#   '2014-10-02T00:16:36Z',
#   4,
#   0,
#   'Tyson Strachan blocked shot from Joel Ward',
#   68,
#   4,
#   7,
#   8470729,
#   'Blocker',
#   8468208,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (2014010077129,
#   'Blocked Shot',
#   2,
#   'REGULAR',
#   '07:41',
#   '2014-10-02T00:16:44Z',
#   4,
#   0,
#   'Marcus Foligno blocked shot from John Carlson',
#   64,
#   3,
#   7,
#   8475220,
#   'Blocker',
#   8474590,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (2014010077130,
#   'Missed Shot',
#   2,
#   'REGULAR',
#   '08:15',
#   '2014-10-02T00:17:19Z',
#   4,
#   0,
#   'Connor Carrick - Over Net',
#   48,
#   15,
#   15,
#   8476941,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077131,
#   'Shot',
#   2,
#   'REGULAR',
#   '08:38',
#   '2014-10-02T00:17:42Z',
#   4,
#   0,
#   'Evgeny Kuznetsov Wrist Shot saved by Jhonas Enroth',
#   85,
#   -21,
#   15,
#   8475744,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077132,
#   'Shot',
#   2,
#   'REGULAR',
#   '08:39',
#   '2014-10-02T00:17:46Z',
#   4,
#   0,
#   'Jason Chimera Wrist Shot saved by Jhonas Enroth',
#   80,
#   -3,
#   15,
#   8466251,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077134,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '08:40',
#   '2014-10-02T00:17:58Z',
#   4,
#   0,
#   'Chris Conner faceoff won against Tyler Ennis',
#   69,
#   -22,
#   15,
#   8472368,
#   'Winner',
#   8474589,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077133,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '08:40',
#   '2014-10-02T00:17:58Z',
#   4,
#   0,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077135,
#   'Giveaway',
#   2,
#   'REGULAR',
#   '08:49',
#   '2014-10-02T00:18:29Z',
#   4,
#   0,
#   'Giveaway by Marcus Johansson',
#   51,
#   -32,
#   15,
#   8475149,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077136,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '08:57',
#   '2014-10-02T00:18:50Z',
#   4,
#   0,
#   'Offside',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077137,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '08:57',
#   '2014-10-02T00:18:55Z',
#   4,
#   0,
#   'Evgeny Kuznetsov faceoff won against Tyler Ennis',
#   -20,
#   22,
#   15,
#   8475744,
#   'Winner',
#   8474589,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077138,
#   'Missed Shot',
#   2,
#   'REGULAR',
#   '09:49',
#   '2014-10-02T00:19:56Z',
#   4,
#   0,
#   'Jason Chimera - Wide of Net',
#   74,
#   17,
#   15,
#   8466251,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077139,
#   'Hit',
#   2,
#   'REGULAR',
#   '11:37',
#   '2014-10-02T00:21:44Z',
#   4,
#   0,
#   'Drew Stafford hit John Carlson',
#   -94,
#   -35,
#   7,
#   8471226,
#   'Hitter',
#   8474590,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077140,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '12:04',
#   '2014-10-02T00:22:29Z',
#   4,
#   0,
#   'Icing',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077141,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '12:04',
#   '2014-10-02T00:22:32Z',
#   4,
#   0,
#   'Kris Newbury faceoff won against Sam Reinhart',
#   -69,
#   -22,
#   15,
#   8470232,
#   'Winner',
#   8477933,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077142,
#   'Hit',
#   2,
#   'REGULAR',
#   '12:41',
#   '2014-10-02T00:23:16Z',
#   4,
#   0,
#   'Kris Newbury hit Marcus Foligno',
#   97,
#   -20,
#   15,
#   8470232,
#   'Hitter',
#   8475220,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077143,
#   'Hit',
#   2,
#   'REGULAR',
#   '12:46',
#   '2014-10-02T00:23:21Z',
#   4,
#   0,
#   'Garrett Mitchell hit Marcus Foligno',
#   98,
#   -32,
#   15,
#   8475291,
#   'Hitter',
#   8475220,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077144,
#   'Missed Shot',
#   2,
#   'REGULAR',
#   '12:57',
#   '2014-10-02T00:23:33Z',
#   4,
#   0,
#   'Jake McCabe - Wide of Net',
#   -41,
#   23,
#   7,
#   8476931,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077145,
#   'Giveaway',
#   2,
#   'REGULAR',
#   '13:01',
#   '2014-10-02T00:23:36Z',
#   4,
#   0,
#   'Giveaway by Chris Stewart',
#   -52,
#   -36,
#   7,
#   8473485,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077146,
#   'Hit',
#   2,
#   'REGULAR',
#   '13:10',
#   '2014-10-02T00:23:45Z',
#   4,
#   0,
#   'Josh Gorges hit Joel Ward',
#   96,
#   32,
#   7,
#   8470324,
#   'Hitter',
#   8468208,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077147,
#   'Shot',
#   2,
#   'REGULAR',
#   '13:11',
#   '2014-10-02T00:23:47Z',
#   4,
#   0,
#   'Karl Alzner Slap Shot saved by Jhonas Enroth',
#   36,
#   16,
#   15,
#   8473991,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077148,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '13:12',
#   '2014-10-02T00:24:02Z',
#   4,
#   0,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077149,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '13:12',
#   '2014-10-02T00:25:41Z',
#   4,
#   0,
#   'Brian Flynn faceoff won against Evgeny Kuznetsov',
#   69,
#   22,
#   7,
#   8476808,
#   'Winner',
#   8475744,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077151,
#   'Penalty',
#   2,
#   'REGULAR',
#   '14:49',
#   '2014-10-02T00:27:38Z',
#   4,
#   0,
#   'John Erskine Interference against Tyler Ennis',
#   -97,
#   -13,
#   15,
#   8467365,
#   'PenaltyOn',
#   8474589,
#   'DrewBy',
#   None,
#   None,
#   None,
#   None),
#  (2014010077150,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '14:49',
#   '2014-10-02T00:27:38Z',
#   4,
#   0,
#   'TV timeout',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077152,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '14:49',
#   '2014-10-02T00:29:23Z',
#   4,
#   0,
#   'Joel Ward faceoff won against Tyler Ennis',
#   -69,
#   -22,
#   15,
#   8468208,
#   'Winner',
#   8474589,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077153,
#   'Hit',
#   2,
#   'REGULAR',
#   '17:15',
#   '2014-10-02T00:32:09Z',
#   4,
#   0,
#   'Dane Byers hit Tyson Strachan',
#   93,
#   38,
#   15,
#   8471261,
#   'Hitter',
#   8470729,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077154,
#   'Missed Shot',
#   2,
#   'REGULAR',
#   '17:26',
#   '2014-10-02T00:32:23Z',
#   4,
#   0,
#   'Marcus Foligno - Goalpost',
#   -71,
#   2,
#   7,
#   8475220,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077155,
#   'Goal',
#   2,
#   'REGULAR',
#   '17:28',
#   '2014-10-02T00:32:32Z',
#   5,
#   0,
#   'Marcus Foligno (1) Wrist Shot, assists: Tyson Strachan (1), Chris Stewart (2)',
#   -83,
#   6,
#   7,
#   8475220,
#   'Scorer',
#   8470729,
#   'Assist',
#   8473485,
#   'Assist',
#   8474651,
#   'Goalie'),
#  (2014010077156,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '17:28',
#   '2014-10-02T00:32:55Z',
#   5,
#   0,
#   'Kris Newbury faceoff won against Zemgus Girgensons',
#   0,
#   0,
#   15,
#   8470232,
#   'Winner',
#   8476878,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077157,
#   'Hit',
#   2,
#   'REGULAR',
#   '18:09',
#   '2014-10-02T00:33:41Z',
#   5,
#   0,
#   'Tyler Myers hit Garrett Mitchell',
#   33,
#   38,
#   7,
#   8474574,
#   'Hitter',
#   8475291,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077158,
#   'Missed Shot',
#   2,
#   'REGULAR',
#   '18:19',
#   '2014-10-02T00:33:50Z',
#   5,
#   0,
#   'Joel Ward - Wide of Net',
#   56,
#   36,
#   15,
#   8468208,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077159,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '18:41',
#   '2014-10-02T00:34:16Z',
#   5,
#   0,
#   'Puck in Crowd',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077160,
#   'Penalty',
#   2,
#   'REGULAR',
#   '18:41',
#   '2014-10-02T00:34:43Z',
#   5,
#   0,
#   'Nikita Zadorov Delaying Game - Puck over glass',
#   32,
#   40,
#   7,
#   8477507,
#   'PenaltyOn',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077161,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '18:41',
#   '2014-10-02T00:34:54Z',
#   5,
#   0,
#   'Marcus Johansson faceoff won against Drew Stafford',
#   69,
#   22,
#   15,
#   8475149,
#   'Winner',
#   8471226,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077162,
#   'Missed Shot',
#   2,
#   'REGULAR',
#   '18:48',
#   '2014-10-02T00:34:59Z',
#   5,
#   0,
#   'Troy Brouwer - Wide of Net',
#   36,
#   32,
#   15,
#   8471426,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077163,
#   'Hit',
#   2,
#   'REGULAR',
#   '19:00',
#   '2014-10-02T00:35:12Z',
#   5,
#   0,
#   'Troy Brouwer hit Tyler Ennis',
#   -61,
#   30,
#   15,
#   8471426,
#   'Hitter',
#   8474589,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077164,
#   'Shot',
#   2,
#   'REGULAR',
#   '19:28',
#   '2014-10-02T00:35:40Z',
#   5,
#   0,
#   'Brooks Laich Wrist Shot saved by Jhonas Enroth',
#   85,
#   -7,
#   15,
#   8469639,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077165,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '19:30',
#   '2014-10-02T00:35:48Z',
#   5,
#   0,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077166,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '19:30',
#   '2014-10-02T00:36:01Z',
#   5,
#   0,
#   'Evgeny Kuznetsov faceoff won against Marcus Foligno',
#   69,
#   -22,
#   15,
#   8475744,
#   'Winner',
#   8475220,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077167,
#   'Period End',
#   2,
#   'REGULAR',
#   '20:00',
#   '2014-10-02T00:37:53Z',
#   5,
#   0,
#   'End of 2nd Period',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077168,
#   'Period Official',
#   2,
#   'REGULAR',
#   '20:00',
#   '2014-10-02T00:37:55Z',
#   5,
#   0,
#   'Period Official',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077169,
#   'Period Ready',
#   3,
#   'REGULAR',
#   '00:00',
#   '2014-10-02T00:53:54Z',
#   5,
#   0,
#   'Period Ready',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077170,
#   'Period Start',
#   3,
#   'REGULAR',
#   '00:00',
#   '2014-10-02T00:54:59Z',
#   5,
#   0,
#   'Period Start',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077171,
#   'Faceoff',
#   3,
#   'REGULAR',
#   '00:00',
#   '2014-10-02T00:54:59Z',
#   5,
#   0,
#   'Zemgus Girgensons faceoff won against Joel Ward',
#   0,
#   0,
#   7,
#   8476878,
#   'Winner',
#   8468208,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077172,
#   'Blocked Shot',
#   3,
#   'REGULAR',
#   '00:58',
#   '2014-10-02T00:56:04Z',
#   5,
#   0,
#   'Brian Flynn blocked shot from Patrick Wey',
#   -80,
#   30,
#   7,
#   8476808,
#   'Blocker',
#   8475275,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (2014010077173,
#   'Takeaway',
#   3,
#   'REGULAR',
#   '01:18',
#   '2014-10-02T00:56:23Z',
#   5,
#   0,
#   'Takeaway by Tyler Ennis',
#   8,
#   5,
#   7,
#   8474589,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077174,
#   'Shot',
#   3,
#   'REGULAR',
#   '01:44',
#   '2014-10-02T00:56:50Z',
#   5,
#   0,
#   'Matt Moulson Wrist Shot saved by Philipp Grubauer',
#   79,
#   -3,
#   7,
#   8470852,
#   'Shooter',
#   8475831,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077175,
#   'Hit',
#   3,
#   'REGULAR',
#   '02:21',
#   '2014-10-02T00:57:26Z',
#   5,
#   0,
#   'Tyson Strachan hit Kris Newbury',
#   -50,
#   -40,
#   7,
#   8470729,
#   'Hitter',
#   8470232,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077176,
#   'Shot',
#   3,
#   'REGULAR',
#   '02:27',
#   '2014-10-02T00:57:33Z',
#   5,
#   0,
#   'Cody Hodgson Backhand saved by Philipp Grubauer',
#   77,
#   0,
#   7,
#   8474570,
#   'Shooter',
#   8475831,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077177,
#   'Goal',
#   3,
#   'REGULAR',
#   '02:39',
#   '2014-10-02T00:57:44Z',
#   5,
#   1,
#   'Jason Chimera (1) Snap Shot, assists: Garrett Mitchell (2), Connor Carrick (1)',
#   -54,
#   25,
#   15,
#   8466251,
#   'Scorer',
#   8475291,
#   'Assist',
#   8476941,
#   'Assist',
#   8473523,
#   'Goalie'),
#  (2014010077178,
#   'Faceoff',
#   3,
#   'REGULAR',
#   '02:39',
#   '2014-10-02T00:58:17Z',
#   5,
#   1,
#   'Evgeny Kuznetsov faceoff won against Sam Reinhart',
#   0,
#   0,
#   15,
#   8475744,
#   'Winner',
#   8477933,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077179,
#   'Missed Shot',
#   3,
#   'REGULAR',
#   '02:51',
#   '2014-10-02T00:58:39Z',
#   5,
#   1,
#   'Marcus Johansson - Over Net',
#   -62,
#   28,
#   15,
#   8475149,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077180,
#   'Stoppage',
#   3,
#   'REGULAR',
#   '02:51',
#   '2014-10-02T00:58:40Z',
#   5,
#   1,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077181,
#   'Faceoff',
#   3,
#   'REGULAR',
#   '02:51',
#   '2014-10-02T00:58:52Z',
#   5,
#   1,
#   'Evgeny Kuznetsov faceoff won against Sam Reinhart',
#   -69,
#   22,
#   15,
#   8475744,
#   'Winner',
#   8477933,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077182,
#   'Blocked Shot',
#   3,
#   'REGULAR',
#   '02:57',
#   '2014-10-02T00:59:02Z',
#   5,
#   1,
#   'Marcus Foligno blocked shot from John Carlson',
#   -48,
#   24,
#   7,
#   8475220,
#   'Blocker',
#   8474590,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (2014010077183,
#   'Stoppage',
#   3,
#   'REGULAR',
#   '03:00',
#   '2014-10-02T00:59:04Z',
#   5,
#   1,
#   'Offside',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077184,
#   'Faceoff',
#   3,
#   'REGULAR',
#   '03:00',
#   '2014-10-02T00:59:26Z',
#   5,
#   1,
#   'Evgeny Kuznetsov faceoff won against Zemgus Girgensons',
#   20,
#   22,
#   15,
#   8475744,
#   'Winner',
#   8476878,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077185,
#   'Hit',
#   3,
#   'REGULAR',
#   '03:28',
#   '2014-10-02T00:59:56Z',
#   5,
#   1,
#   'Patrick Wey hit Zemgus Girgensons',
#   92,
#   -36,
#   15,
#   8475275,
#   'Hitter',
#   8476878,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077186,
#   'Blocked Shot',
#   3,
#   'REGULAR',
#   '04:16',
#   '2014-10-02T01:00:44Z',
#   5,
#   1,
#   'Tyson Strachan blocked shot from Joel Ward',
#   -59,
#   12,
#   7,
#   8470729,
#   'Blocker',
#   8468208,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (2014010077187,
#   'Giveaway',
#   3,
#   'REGULAR',
#   '04:28',
#   '2014-10-02T01:01:11Z',
#   5,
#   1,
#   'Giveaway by Josh Gorges',
#   -95,
#   29,
#   7,
#   8470324,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077188,
#   'Shot',
#   3,
#   'REGULAR',
#   '04:31',
#   '2014-10-02T01:00:58Z',
#   5,
#   1,
#   'Andre Burakovsky Wrist Shot saved by Jhonas Enroth',
#   -73,
#   -3,
#   15,
#   8477444,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077189,
#   'Missed Shot',
#   3,
#   'REGULAR',
#   '04:58',
#   '2014-10-02T01:01:26Z',
#   5,
#   1,
#   'John Carlson - Wide of Net',
#   -40,
#   6,
#   15,
#   8474590,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077190,
#   'Takeaway',
#   3,
#   'REGULAR',
#   '05:18',
#   '2014-10-02T01:01:45Z',
#   5,
#   1,
#   'Takeaway by Tyler Myers',
#   8,
#   25,
#   7,
#   8474574,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077191,
#   'Shot',
#   3,
#   'REGULAR',
#   '05:23',
#   '2014-10-02T01:01:51Z',
#   5,
#   1,
#   'Cody Hodgson Backhand saved by Philipp Grubauer',
#   53,
#   32,
#   7,
#   8474570,
#   'Shooter',
#   8475831,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077192,
#   'Hit',
#   3,
#   'REGULAR',
#   '05:29',
#   '2014-10-02T01:01:57Z',
#   5,
#   1,
#   'Mikhail Grigorenko hit Kris Newbury',
#   61,
#   -41,
#   7,
#   8476888,
#   'Hitter',
#   8470232,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077193,
#   'Missed Shot',
#   3,
#   'REGULAR',
#   '05:49',
#   '2014-10-02T01:02:16Z',
#   5,
#   1,
#   'Kris Newbury - Wide of Net',
#   -48,
#   -15,
#   15,
#   8470232,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077194,
#   'Hit',
#   3,
#   'REGULAR',
#   '06:06',
#   '2014-10-02T01:02:33Z',
#   5,
#   1,
#   'Dane Byers hit Sam Reinhart',
#   -39,
#   26,
#   15,
#   8471261,
#   'Hitter',
#   8477933,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010077195,
#   'Shot',
#   3,
#   'REGULAR',
#   '06:17',
#   '2014-10-02T01:02:44Z',
#   5,
#   1,
#   'Patrick Wey Wrist Shot saved by Jhonas Enroth',
#   -40,
#   33,
#   15,
#   8475275,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077196,
#   'Stoppage',
#   3,
#   'REGULAR',
#   '06:18',
#   '2014-10-02T01:02:56Z',
#   5,
#   1,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077197,
#   'Faceoff',
#   3,
#   'REGULAR',
#   '06:18',
#   '2014-10-02T01:04:25Z',
#   5,
#   1,
#   'Evgeny Kuznetsov faceoff won against Sam Reinhart',
#   -69,
#   22,
#   15,
#   8475744,
#   'Winner',
#   8477933,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077198,
#   'Giveaway',
#   3,
#   'REGULAR',
#   '06:55',
#   '2014-10-02T01:05:30Z',
#   5,
#   1,
#   'Giveaway by Garrett Mitchell',
#   75,
#   12,
#   15,
#   8475291,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077199,
#   'Shot',
#   3,
#   'REGULAR',
#   '07:06',
#   '2014-10-02T01:05:42Z',
#   5,
#   1,
#   'Sam Reinhart Wrist Shot saved by Philipp Grubauer',
#   48,
#   17,
#   7,
#   8477933,
#   'Shooter',
#   8475831,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077200,
#   'Goal',
#   3,
#   'REGULAR',
#   '07:10',
#   '2014-10-02T01:05:48Z',
#   6,
#   1,
#   'Sam Reinhart (1) Wrist Shot, assists: Chris Stewart (3), Marcus Foligno (2)',
#   69,
#   -5,
#   7,
#   8477933,
#   'Scorer',
#   8473485,
#   'Assist',
#   8475220,
#   'Assist',
#   8475831,
#   'Goalie'),
#  (2014010077201,
#   'Faceoff',
#   3,
#   'REGULAR',
#   '07:10',
#   '2014-10-02T01:06:18Z',
#   6,
#   1,
#   'Zemgus Girgensons faceoff won against Andre Burakovsky',
#   0,
#   0,
#   7,
#   8476878,
#   'Winner',
#   8477444,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077202,
#   'Stoppage',
#   3,
#   'REGULAR',
#   '07:18',
#   '2014-10-02T01:06:33Z',
#   6,
#   1,
#   'Icing',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077203,
#   'Faceoff',
#   3,
#   'REGULAR',
#   '07:18',
#   '2014-10-02T01:06:39Z',
#   6,
#   1,
#   'Casey Wellman faceoff won against Zemgus Girgensons',
#   -69,
#   22,
#   15,
#   8475602,
#   'Winner',
#   8476878,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077204,
#   'Giveaway',
#   3,
#   'REGULAR',
#   '07:33',
#   '2014-10-02T01:07:09Z',
#   6,
#   1,
#   'Giveaway by Tyler Myers',
#   -45,
#   23,
#   7,
#   8474574,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010077205,
#   'Shot',
#   3,
#   'REGULAR',
#   '07:35',
#   '2014-10-02T01:07:14Z',
#   6,
#   1,
#   'Casey Wellman Wrist Shot saved by Jhonas Enroth',
#   -69,
#   1,
#   15,
#   8475602,
#   'Shooter',
#   8473523,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010077207,
#   'Faceoff',
#   3,
#   'REGULAR',
#   '07:36',
#   '2014-10-02T01:07:37Z',
#   6,
#   1,
#   'Casey Wellman faceoff won against Tyler Ennis',
#   -69,
#   22,
#   15,
#   8475602,
#   'Winner',
#   8474589,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010077206,
#   'Stoppage',
#   3,
#   'REGULAR',
#   '07:36',
#   '2014-10-02T01:07:37Z',
#   6,
#   1,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
# ...
#   'Faceoff',
#   2,
#   'REGULAR',
#   '02:14',
#   '2014-10-02T01:33:34Z',
#   0,
#   0,
#   'Michael Bournival faceoff won against Brad Richards',
#   69,
#   22,
#   8,
#   8475739,
#   'Winner',
#   8467389,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010078120,
#   'Takeaway',
#   2,
#   'REGULAR',
#   '02:33',
#   '2014-10-02T01:33:54Z',
#   0,
#   0,
#   'Takeaway by Michael Bournival',
#   -85,
#   -39,
#   8,
#   8475739,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078121,
#   'Shot',
#   2,
#   'REGULAR',
#   '02:55',
#   '2014-10-02T01:34:16Z',
#   0,
#   0,
#   'Patrick Kane Wrist Shot saved by Carey Price',
#   89,
#   -14,
#   16,
#   8474141,
#   'Shooter',
#   8471679,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010078122,
#   'Shot',
#   2,
#   'REGULAR',
#   '03:06',
#   '2014-10-02T01:34:27Z',
#   0,
#   0,
#   'Brad Richards Wrist Shot saved by Carey Price',
#   81,
#   -14,
#   16,
#   8467389,
#   'Shooter',
#   8471679,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010078123,
#   'Missed Shot',
#   2,
#   'REGULAR',
#   '03:47',
#   '2014-10-02T01:35:08Z',
#   0,
#   0,
#   'Ben Smith - Wide of Net',
#   74,
#   13,
#   16,
#   8474727,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078124,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '04:06',
#   '2014-10-02T01:35:28Z',
#   0,
#   0,
#   'Icing',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078125,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '04:06',
#   '2014-10-02T01:35:40Z',
#   0,
#   0,
#   'Jonathan Toews faceoff won against Sven Andrighetto',
#   -69,
#   22,
#   16,
#   8473604,
#   'Winner',
#   8477413,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010078126,
#   'Hit',
#   2,
#   'REGULAR',
#   '04:12',
#   '2014-10-02T01:35:53Z',
#   0,
#   0,
#   'Jacob De La Rose hit Brent Seabrook',
#   -93,
#   -29,
#   8,
#   8477455,
#   'Hitter',
#   8470607,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078127,
#   'Giveaway',
#   2,
#   'REGULAR',
#   '04:29',
#   '2014-10-02T01:36:11Z',
#   0,
#   0,
#   'Giveaway by David Johnny Oduya',
#   -96,
#   -5,
#   16,
#   8469665,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078128,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '04:43',
#   '2014-10-02T01:36:42Z',
#   0,
#   0,
#   'High Stick',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078129,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '04:43',
#   '2014-10-02T01:36:51Z',
#   0,
#   0,
#   'Jake Dowell faceoff won against Andrew Shaw',
#   -20,
#   22,
#   8,
#   8471352,
#   'Winner',
#   8476381,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010078130,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '04:56',
#   '2014-10-02T01:37:12Z',
#   0,
#   0,
#   'Offside',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078131,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '04:56',
#   '2014-10-02T01:37:22Z',
#   0,
#   0,
#   'Jake Dowell faceoff won against Andrew Shaw',
#   -20,
#   -22,
#   8,
#   8471352,
#   'Winner',
#   8476381,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010078132,
#   'Hit',
#   2,
#   'REGULAR',
#   '05:11',
#   '2014-10-02T01:37:52Z',
#   0,
#   0,
#   'Alexei Emelin hit David Johnny Oduya',
#   39,
#   4,
#   8,
#   8471296,
#   'Hitter',
#   8469665,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078133,
#   'Shot',
#   2,
#   'REGULAR',
#   '05:12',
#   '2014-10-02T01:37:52Z',
#   0,
#   0,
#   'Andrew Shaw Wrist Shot saved by Carey Price',
#   67,
#   16,
#   16,
#   8476381,
#   'Shooter',
#   8471679,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010078134,
#   'Hit',
#   2,
#   'REGULAR',
#   '05:31',
#   '2014-10-02T01:38:14Z',
#   0,
#   0,
#   'Kris Versteeg hit Alexei Emelin',
#   90,
#   -38,
#   16,
#   8471346,
#   'Hitter',
#   8471296,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078135,
#   'Hit',
#   2,
#   'REGULAR',
#   '05:38',
#   '2014-10-02T01:38:18Z',
#   0,
#   0,
#   'Trevor van Riemsdyk hit Gabriel Dumont',
#   -94,
#   31,
#   16,
#   8477845,
#   'Hitter',
#   8475254,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078136,
#   'Hit',
#   2,
#   'REGULAR',
#   '06:04',
#   '2014-10-02T01:38:44Z',
#   0,
#   0,
#   'Jiri Sekac hit Jeremy Morin',
#   29,
#   -40,
#   8,
#   8478137,
#   'Hitter',
#   8475214,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078137,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '06:13',
#   '2014-10-02T01:38:55Z',
#   0,
#   0,
#   'Icing',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078138,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '06:13',
#   '2014-10-02T01:39:11Z',
#   0,
#   0,
#   'Marcus Kruger faceoff won against Michael Bournival',
#   -69,
#   22,
#   16,
#   8475323,
#   'Winner',
#   8475739,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010078139,
#   'Blocked Shot',
#   2,
#   'REGULAR',
#   '06:43',
#   '2014-10-02T01:39:45Z',
#   0,
#   0,
#   'Davis Drewiske blocked shot from Jeremy Morin',
#   80,
#   -19,
#   8,
#   8474518,
#   'Blocker',
#   8475214,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (2014010078140,
#   'Hit',
#   2,
#   'REGULAR',
#   '06:57',
#   '2014-10-02T01:39:59Z',
#   0,
#   0,
#   'Brandon Saad hit Davis Drewiske',
#   50,
#   -39,
#   16,
#   8476438,
#   'Hitter',
#   8474518,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078141,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '07:00',
#   '2014-10-02T01:40:25Z',
#   0,
#   0,
#   'Puck in Crowd',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078142,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '07:00',
#   '2014-10-02T01:42:03Z',
#   0,
#   0,
#   'Brad Richards faceoff won against Michael Bournival',
#   -69,
#   -22,
#   16,
#   8467389,
#   'Winner',
#   8475739,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010078143,
#   'Giveaway',
#   2,
#   'REGULAR',
#   '07:06',
#   '2014-10-02T01:42:20Z',
#   0,
#   0,
#   'Giveaway by Duncan Keith',
#   -95,
#   7,
#   16,
#   8470281,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078144,
#   'Shot',
#   2,
#   'REGULAR',
#   '07:15',
#   '2014-10-02T01:42:29Z',
#   0,
#   0,
#   'Brad Richards Wrist Shot saved by Carey Price',
#   63,
#   -1,
#   16,
#   8467389,
#   'Shooter',
#   8471679,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010078145,
#   'Hit',
#   2,
#   'REGULAR',
#   '07:24',
#   '2014-10-02T01:42:38Z',
#   0,
#   0,
#   'Davis Drewiske hit Brandon Saad',
#   75,
#   -40,
#   8,
#   8474518,
#   'Hitter',
#   8476438,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078146,
#   'Hit',
#   2,
#   'REGULAR',
#   '07:33',
#   '2014-10-02T01:42:49Z',
#   0,
#   0,
#   'Michael Bournival hit Patrick Kane',
#   81,
#   -40,
#   8,
#   8475739,
#   'Hitter',
#   8474141,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078147,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '07:33',
#   '2014-10-02T01:42:58Z',
#   0,
#   0,
#   'Net Off',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078148,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '07:33',
#   '2014-10-02T01:43:27Z',
#   0,
#   0,
#   'Jonathan Toews faceoff won against Sven Andrighetto',
#   -20,
#   22,
#   16,
#   8473604,
#   'Winner',
#   8477413,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010078149,
#   'Hit',
#   2,
#   'REGULAR',
#   '07:42',
#   '2014-10-02T01:43:41Z',
#   0,
#   0,
#   'Greg Pateryn hit Patrick Sharp',
#   -24,
#   38,
#   8,
#   8474688,
#   'Hitter',
#   8469544,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078150,
#   'Hit',
#   2,
#   'REGULAR',
#   '08:12',
#   '2014-10-02T01:44:11Z',
#   0,
#   0,
#   'Alexei Emelin hit Ben Smith',
#   64,
#   40,
#   8,
#   8471296,
#   'Hitter',
#   8474727,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078151,
#   'Takeaway',
#   2,
#   'REGULAR',
#   '08:21',
#   '2014-10-02T01:44:20Z',
#   0,
#   0,
#   'Takeaway by Jacob De La Rose',
#   74,
#   28,
#   8,
#   8477455,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078152,
#   'Shot',
#   2,
#   'REGULAR',
#   '08:33',
#   '2014-10-02T01:44:31Z',
#   0,
#   0,
#   'Bryan Bickell Wrist Shot saved by Carey Price',
#   83,
#   -6,
#   16,
#   8471254,
#   'Shooter',
#   8471679,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010078153,
#   'Hit',
#   2,
#   'REGULAR',
#   '09:01',
#   '2014-10-02T01:45:00Z',
#   0,
#   0,
#   'Bryan Bickell hit Jarred Tinordi',
#   81,
#   2,
#   16,
#   8471254,
#   'Hitter',
#   8475797,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078154,
#   'Hit',
#   2,
#   'REGULAR',
#   '09:31',
#   '2014-10-02T01:45:30Z',
#   0,
#   0,
#   'Michal Rozsival hit Jiri Sekac',
#   -46,
#   38,
#   16,
#   8465058,
#   'Hitter',
#   8478137,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078155,
#   'Takeaway',
#   2,
#   'REGULAR',
#   '09:38',
#   '2014-10-02T01:45:49Z',
#   0,
#   0,
#   'Takeaway by Jiri Sekac',
#   -42,
#   38,
#   8,
#   8478137,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078156,
#   'Shot',
#   2,
#   'REGULAR',
#   '09:40',
#   '2014-10-02T01:45:39Z',
#   0,
#   0,
#   'Lars Eller Snap Shot saved by Antti Raanta',
#   -66,
#   3,
#   8,
#   8474189,
#   'Shooter',
#   8477293,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010078157,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '09:40',
#   '2014-10-02T01:45:54Z',
#   0,
#   0,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078158,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '09:40',
#   '2014-10-02T01:46:01Z',
#   0,
#   0,
#   'Gabriel Dumont faceoff won against Jeremy Morin',
#   -69,
#   22,
#   8,
#   8475254,
#   'Winner',
#   8475214,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010078159,
#   'Giveaway',
#   2,
#   'REGULAR',
#   '09:50',
#   '2014-10-02T01:46:24Z',
#   0,
#   0,
#   'Giveaway by Jeremy Morin',
#   -83,
#   33,
#   16,
#   8475214,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078160,
#   'Shot',
#   2,
#   'REGULAR',
#   '09:59',
#   '2014-10-02T01:46:34Z',
#   0,
#   0,
#   'Gabriel Dumont Wrist Shot saved by Antti Raanta',
#   -72,
#   -15,
#   8,
#   8475254,
#   'Shooter',
#   8477293,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010078161,
#   'Hit',
#   2,
#   'REGULAR',
#   '10:05',
#   '2014-10-02T01:46:39Z',
#   0,
#   0,
#   'Jeremy Morin hit Drayson Bowman',
#   -75,
#   -12,
#   16,
#   8475214,
#   'Hitter',
#   8474137,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078162,
#   'Penalty',
#   2,
#   'REGULAR',
#   '10:11',
#   '2014-10-02T01:46:52Z',
#   0,
#   0,
#   'Gabriel Dumont Hooking against Brandon Mashinter',
#   -85,
#   35,
#   8,
#   8475254,
#   'PenaltyOn',
#   8474850,
#   'DrewBy',
#   None,
#   None,
#   None,
#   None),
#  (2014010078163,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '10:11',
#   '2014-10-02T01:47:12Z',
#   0,
#   0,
#   'TV timeout',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078164,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '10:11',
#   '2014-10-02T01:49:08Z',
#   0,
#   0,
#   'Jonathan Toews faceoff won against Lars Eller',
#   69,
#   22,
#   16,
#   8473604,
#   'Winner',
#   8474189,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010078165,
#   'Takeaway',
#   2,
#   'REGULAR',
#   '10:30',
#   '2014-10-02T01:49:42Z',
#   0,
#   0,
#   'Takeaway by Lars Eller',
#   48,
#   -4,
#   8,
#   8474189,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078166,
#   'Hit',
#   2,
#   'REGULAR',
#   '10:40',
#   '2014-10-02T01:49:52Z',
#   0,
#   0,
#   'Patrick Sharp hit Dale Weise',
#   -94,
#   -30,
#   16,
#   8469544,
#   'Hitter',
#   8474668,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078167,
#   'Hit',
#   2,
#   'REGULAR',
#   '10:52',
#   '2014-10-02T01:50:03Z',
#   0,
#   0,
#   'Greg Pateryn hit Jonathan Toews',
#   67,
#   39,
#   8,
#   8474688,
#   'Hitter',
#   8473604,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078168,
#   'Hit',
#   2,
#   'REGULAR',
#   '11:02',
#   '2014-10-02T01:50:14Z',
#   0,
#   0,
#   'Greg Pateryn hit Andrew Shaw',
#   96,
#   12,
#   8,
#   8474688,
#   'Hitter',
#   8476381,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078169,
#   'Shot',
#   2,
#   'REGULAR',
#   '12:14',
#   '2014-10-02T01:51:26Z',
#   0,
#   0,
#   'Kris Versteeg Wrist Shot saved by Carey Price',
#   82,
#   -25,
#   16,
#   8471346,
#   'Shooter',
#   8471679,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010078170,
#   'Missed Shot',
#   2,
#   'REGULAR',
#   '12:20',
#   '2014-10-02T01:51:32Z',
#   0,
#   0,
#   'Kris Versteeg - Over Net',
#   54,
#   9,
#   16,
#   8471346,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078171,
#   'Hit',
#   2,
#   'REGULAR',
#   '12:23',
#   '2014-10-02T01:51:35Z',
#   0,
#   0,
#   'Gabriel Dumont hit Michal Rozsival',
#   55,
#   -40,
#   8,
#   8475254,
#   'Hitter',
#   8465058,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078172,
#   'Shot',
#   2,
#   'REGULAR',
#   '12:52',
#   '2014-10-02T01:52:04Z',
#   0,
#   0,
#   'Rene Bourque Wrist Shot saved by Antti Raanta',
#   -72,
#   -19,
#   8,
#   8471504,
#   'Shooter',
#   8477293,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010078173,
#   'Hit',
#   2,
#   'REGULAR',
#   '13:13',
#   '2014-10-02T01:52:25Z',
#   0,
#   0,
#   'Marcus Kruger hit Jiri Sekac',
#   28,
#   38,
#   16,
#   8475323,
#   'Hitter',
#   8478137,
#   'Hittee',
#   None,
#   None,
#   None,
#   None),
#  (2014010078174,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '13:26',
#   '2014-10-02T01:52:41Z',
#   0,
#   0,
#   'Icing',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078175,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '13:26',
#   '2014-10-02T01:52:57Z',
#   0,
#   0,
#   'Jacob De La Rose faceoff won against Jonathan Toews',
#   -69,
#   22,
#   8,
#   8477455,
#   'Winner',
#   8473604,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010078176,
#   'Blocked Shot',
#   2,
#   'REGULAR',
#   '13:33',
#   '2014-10-02T01:53:11Z',
#   0,
#   0,
#   'David Johnny Oduya blocked shot from Christian Thomas',
#   -69,
#   5,
#   16,
#   8469665,
#   'Blocker',
#   8475749,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (2014010078177,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '13:34',
#   '2014-10-02T01:53:13Z',
#   0,
#   0,
#   'Puck in Netting',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078178,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '13:34',
#   '2014-10-02T01:53:23Z',
#   0,
#   0,
#   'Jacob De La Rose faceoff won against Jonathan Toews',
#   -69,
#   22,
#   8,
#   8477455,
#   'Winner',
#   8473604,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010078179,
#   'Penalty',
#   2,
#   'REGULAR',
#   '14:16',
#   '2014-10-02T01:54:22Z',
#   0,
#   0,
#   'Patrick Sharp Boarding against Sven Andrighetto',
#   -95,
#   33,
#   16,
#   8469544,
#   'PenaltyOn',
#   8477413,
#   'DrewBy',
#   None,
#   None,
#   None,
#   None),
#  (2014010078180,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '14:16',
#   '2014-10-02T01:54:32Z',
#   0,
#   0,
#   'TV timeout',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078181,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '14:16',
#   '2014-10-02T01:56:27Z',
#   0,
#   0,
#   'Ben Smith faceoff won against Lars Eller',
#   -69,
#   -22,
#   16,
#   8474727,
#   'Winner',
#   8474189,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010078182,
#   'Blocked Shot',
#   2,
#   'REGULAR',
#   '15:49',
#   '2014-10-02T01:58:19Z',
#   0,
#   0,
#   'Ben Smith blocked shot from Alexei Emelin',
#   -60,
#   -5,
#   16,
#   8474727,
#   'Blocker',
#   8471296,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  (2014010078183,
#   'Shot',
#   2,
#   'REGULAR',
#   '16:33',
#   '2014-10-02T01:59:04Z',
#   0,
#   0,
#   'Sven Andrighetto Wrist Shot saved by Antti Raanta',
#   -63,
#   25,
#   8,
#   8477413,
#   'Shooter',
#   8477293,
#   'Goalie',
#   None,
#   None,
#   None,
#   None),
#  (2014010078184,
#   'Stoppage',
#   2,
#   'REGULAR',
#   '16:33',
#   '2014-10-02T01:59:06Z',
#   0,
#   0,
#   'Goalie Stopped',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078185,
#   'Faceoff',
#   2,
#   'REGULAR',
#   '16:33',
#   '2014-10-02T01:59:32Z',
#   0,
#   0,
#   'Brad Richards faceoff won against Michael Bournival',
#   -69,
#   22,
#   16,
#   8467389,
#   'Winner',
#   8475739,
#   'Loser',
#   None,
#   None,
#   None,
#   None),
#  (2014010078186,
#   'Missed Shot',
#   2,
#   'REGULAR',
#   '16:47',
#   '2014-10-02T01:59:50Z',
#   0,
#   0,
#   'Brandon Prust - Wide of Net',
#   -72,
#   16,
#   8,
#   8471283,
#   'Shooter',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078187,
#   'Takeaway',
#   2,
#   'REGULAR',
#   '17:19',
#   '2014-10-02T02:00:22Z',
#   0,
#   0,
#   'Takeaway by Bryan Bickell',
#   37,
#   -28,
#   16,
#   8471254,
#   'PlayerID',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None),
#  (2014010078188,
#   'Blocked Shot',
#   2,
#   'REGULAR',
#   '17:21',
#   '2014-10-02T02:00:24Z',
#   0,
#   0,
#   'Jarred Tinordi blocked shot from Bryan Bickell',
#   79,
#   -10,
#   8,
#   8475797,
#   'Blocker',
#   8471254,
#   'Shooter',
#   None,
#   None,
#   None,
#   None),
#  ...]

# %%
# storing data in sql
query = """ 
            CREATE TABLE DIM_SEASON_TABLE
            ( 
                id INTEGER,
                link VARCHAR(100),
                season INTEGER,
                gameDate VARCHAR(50),
                gameType VARCHAR(50),
                awayTeamId INTEGER,
                homeTeamId INTEGER
            );"""

# %%
# now we need to create our database or place to store the table
con = sqlite3.connect('dsc_550_project.sqlite') 
# commit, keeps the entire transaction, else it will be rolled back once we log out
con.execute(query)
# excecute the create table statement so we have a table set up
con.commit()

# %%
#insert statement, '?' are like the placeholders for the variables
stmt = "INSERT INTO DIM_SEASON_TABLE VALUES(?,?,?,?,?,?,?)"
# normally in sql you would have the insert statemnt above and then the data below
# doing it like this tells sqlite to insert and then we have the values after the comma
con.executemany(stmt, nhlGames.reset_index().values.tolist())
con.commit()

# %%
# creating sel * to see the data
cursor = con.execute('Select * from DIM_SEASON_TABLE')
rows = cursor.fetchall()
rows
# Out:
# [(2014010077,
#   '/api/v1/game/2014010077/feed/live',
#   20142015,
#   '2014-10-01T23:00:00Z',
#   '01',
#   15,
#   7),
#  (2014010079,
#   '/api/v1/game/2014010079/feed/live',
#   20142015,
#   '2014-10-01T23:00:00Z',
#   '01',
#   12,
#   29),
#  (2014010081,
#   '/api/v1/game/2014010081/feed/live',
#   20142015,
#   '2014-10-01T23:30:00Z',
#   '01',
#   5,
#   17),
#  (2014010078,
#   '/api/v1/game/2014010078/feed/live',
#   20142015,
#   '2014-10-02T00:30:00Z',
#   '01',
#   8,
#   16),
#  (2014010080,
#   '/api/v1/game/2014010080/feed/live',
#   20142015,
#   '2014-10-02T01:00:00Z',
#   '01',
#   53,
#   22),
#  (2014010085,
#   '/api/v1/game/2014010085/feed/live',
#   20142015,
#   '2014-10-02T23:00:00Z',
#   '01',
#   2,
#   1),
#  (2014010086,
#   '/api/v1/game/2014010086/feed/live',
#   20142015,
#   '2014-10-02T23:00:00Z',
#   '01',
#   4,
#   15),
#  (2014010088,
#   '/api/v1/game/2014010088/feed/live',
#   20142015,
#   '2014-10-02T23:30:00Z',
#   '01',
#   14,
#   13),
#  (2014010087,
#   '/api/v1/game/2014010087/feed/live',
#   20142015,
#   '2014-10-03T00:00:00Z',
#   '01',
#   30,
#   19),
#  (2014010082,
#   '/api/v1/game/2014010082/feed/live',
#   20142015,
#   '2014-10-03T01:00:00Z',
#   '01',
#   52,
#   20),
#  (2014010083,
#   '/api/v1/game/2014010083/feed/live',
#   20142015,
#   '2014-10-03T01:00:00Z',
#   '01',
#   23,
#   22),
#  (2014010084,
#   '/api/v1/game/2014010084/feed/live',
#   20142015,
#   '2014-10-03T01:00:00Z',
#   '01',
#   26,
#   21),
#  (2014010089,
#   '/api/v1/game/2014010089/feed/live',
#   20142015,
#   '2014-10-03T23:00:00Z',
#   '01',
#   7,
#   12),
#  (2014010090,
#   '/api/v1/game/2014010090/feed/live',
#   20142015,
#   '2014-10-03T23:00:00Z',
#   '01',
#   16,
#   3),
#  (2014010091,
#   '/api/v1/game/2014010091/feed/live',
#   20142015,
#   '2014-10-03T23:30:00Z',
#   '01',
#   8,
#   9),
#  (2014010093,
#   '/api/v1/game/2014010093/feed/live',
#   20142015,
#   '2014-10-03T23:30:00Z',
#   '01',
#   17,
#   10),
#  (2014010094,
#   '/api/v1/game/2014010094/feed/live',
#   20142015,
#   '2014-10-03T23:30:00Z',
#   '01',
#   6,
#   2),
#  (2014010092,
#   '/api/v1/game/2014010092/feed/live',
#   20142015,
#   '2014-10-04T02:00:00Z',
#   '01',
#   28,
#   53),
#  (2014010095,
#   '/api/v1/game/2014010095/feed/live',
#   20142015,
#   '2014-10-04T21:30:00Z',
#   '01',
#   17,
#   6),
#  (2014010098,
#   '/api/v1/game/2014010098/feed/live',
#   20142015,
#   '2014-10-04T23:00:00Z',
#   '01',
#   18,
#   29),
#  (2014010100,
#   '/api/v1/game/2014010100/feed/live',
#   20142015,
#   '2014-10-04T23:00:00Z',
#   '01',
#   13,
#   14),
#  (2014010102,
#   '/api/v1/game/2014010102/feed/live',
#   20142015,
#   '2014-10-04T23:00:00Z',
#   '01',
#   9,
#   8),
#  (2014010103,
#   '/api/v1/game/2014010103/feed/live',
#   20142015,
#   '2014-10-04T23:00:00Z',
#   '01',
#   3,
#   1),
#  (2014010096,
#   '/api/v1/game/2014010096/feed/live',
#   20142015,
#   '2014-10-05T00:00:00Z',
#   '01',
#   20,
#   52),
#  (2014010101,
#   '/api/v1/game/2014010101/feed/live',
#   20142015,
#   '2014-10-05T00:00:00Z',
#   '01',
#   19,
#   30),
#  (2014010097,
#   '/api/v1/game/2014010097/feed/live',
#   20142015,
#   '2014-10-05T02:00:00Z',
#   '01',
#   21,
#   26),
#  (2014010099,
#   '/api/v1/game/2014010099/feed/live',
#   20142015,
#   '2014-10-05T02:00:00Z',
#   '01',
#   22,
#   23),
#  (2014010104,
#   '/api/v1/game/2014010104/feed/live',
#   20142015,
#   '2014-10-05T02:00:00Z',
#   '01',
#   28,
#   24),
#  (2014010105,
#   '/api/v1/game/2014010105/feed/live',
#   20142015,
#   '2014-10-05T19:00:00Z',
#   '01',
#   12,
#   15),
#  (2014020001,
#   '/api/v1/game/2014020001/feed/live',
#   20142015,
#   '2014-10-08T23:00:00Z',
#   '02',
#   8,
#   10),
#  (2014020002,
#   '/api/v1/game/2014020002/feed/live',
#   20142015,
#   '2014-10-08T23:30:00Z',
#   '02',
#   4,
#   6),
#  (2014020004,
#   '/api/v1/game/2014020004/feed/live',
#   20142015,
#   '2014-10-09T02:00:00Z',
#   '02',
#   28,
#   26),
#  (2014020003,
#   '/api/v1/game/2014020003/feed/live',
#   20142015,
#   '2014-10-09T02:00:00Z',
#   '02',
#   23,
#   20),
#  (2014020005,
#   '/api/v1/game/2014020005/feed/live',
#   20142015,
#   '2014-10-09T23:00:00Z',
#   '02',
#   29,
#   7),
#  (2014020006,
#   '/api/v1/game/2014020006/feed/live',
#   20142015,
#   '2014-10-09T23:00:00Z',
#   '02',
#   1,
#   4),
#  (2014020007,
#   '/api/v1/game/2014020007/feed/live',
#   20142015,
#   '2014-10-09T23:00:00Z',
#   '02',
#   24,
#   5),
#  (2014020008,
#   '/api/v1/game/2014020008/feed/live',
#   20142015,
#   '2014-10-09T23:00:00Z',
#   '02',
#   8,
#   15),
#  (2014020009,
#   '/api/v1/game/2014020009/feed/live',
#   20142015,
#   '2014-10-09T23:30:00Z',
#   '02',
#   6,
#   17),
#  (2014020010,
#   '/api/v1/game/2014020010/feed/live',
#   20142015,
#   '2014-10-09T23:30:00Z',
#   '02',
#   13,
#   14),
#  (2014020011,
#   '/api/v1/game/2014020011/feed/live',
#   20142015,
#   '2014-10-10T00:00:00Z',
#   '02',
#   3,
#   19),
#  (2014020012,
#   '/api/v1/game/2014020012/feed/live',
#   20142015,
#   '2014-10-10T00:00:00Z',
#   '02',
#   9,
#   18),
#  (2014020013,
#   '/api/v1/game/2014020013/feed/live',
#   20142015,
#   '2014-10-10T00:30:00Z',
#   '02',
#   16,
#   25),
#  (2014020014,
#   '/api/v1/game/2014020014/feed/live',
#   20142015,
#   '2014-10-10T01:00:00Z',
#   '02',
#   21,
#   30),
#  (2014020015,
#   '/api/v1/game/2014020015/feed/live',
#   20142015,
#   '2014-10-10T01:30:00Z',
#   '02',
#   20,
#   22),
#  (2014020016,
#   '/api/v1/game/2014020016/feed/live',
#   20142015,
#   '2014-10-10T02:00:00Z',
#   '02',
#   52,
#   53),
#  (2014020017,
#   '/api/v1/game/2014020017/feed/live',
#   20142015,
#   '2014-10-10T23:00:00Z',
#   '02',
#   2,
#   12),
#  (2014020026,
#   '/api/v1/game/2014020026/feed/live',
#   20142015,
#   '2014-10-11T23:00:00Z',
#   '02',
#   20,
#   19),
#  (2014020018,
#   '/api/v1/game/2014020018/feed/live',
#   20142015,
#   '2014-10-11T23:00:00Z',
#   '02',
#   15,
#   6),
#  (2014020019,
#   '/api/v1/game/2014020019/feed/live',
#   20142015,
#   '2014-10-11T23:00:00Z',
#   '02',
#   5,
#   10),
#  (2014020020,
#   '/api/v1/game/2014020020/feed/live',
#   20142015,
#   '2014-10-11T23:00:00Z',
#   '02',
#   24,
#   17),
#  (2014020021,
#   '/api/v1/game/2014020021/feed/live',
#   20142015,
#   '2014-10-11T23:00:00Z',
#   '02',
#   9,
#   14),
#  (2014020022,
#   '/api/v1/game/2014020022/feed/live',
#   20142015,
#   '2014-10-11T23:00:00Z',
#   '02',
#   1,
#   13),
#  (2014020023,
#   '/api/v1/game/2014020023/feed/live',
#   20142015,
#   '2014-10-11T23:00:00Z',
#   '02',
#   12,
#   2),
#  (2014020024,
#   '/api/v1/game/2014020024/feed/live',
#   20142015,
#   '2014-10-11T23:00:00Z',
#   '02',
#   8,
#   4),
#  (2014020025,
#   '/api/v1/game/2014020025/feed/live',
#   20142015,
#   '2014-10-11T23:00:00Z',
#   '02',
#   3,
#   29),
#  (2014020027,
#   '/api/v1/game/2014020027/feed/live',
#   20142015,
#   '2014-10-12T00:00:00Z',
#   '02',
#   25,
#   18),
#  (2014020028,
#   '/api/v1/game/2014020028/feed/live',
#   20142015,
#   '2014-10-12T00:30:00Z',
#   '02',
#   7,
#   16),
#  (2014020030,
#   '/api/v1/game/2014020030/feed/live',
#   20142015,
#   '2014-10-12T01:00:00Z',
#   '02',
#   26,
#   53),
#  (2014020029,
#   '/api/v1/game/2014020029/feed/live',
#   20142015,
#   '2014-10-12T01:00:00Z',
#   '02',
#   30,
#   21),
#  (2014020031,
#   '/api/v1/game/2014020031/feed/live',
#   20142015,
#   '2014-10-12T02:00:00Z',
#   '02',
#   22,
#   23),
#  (2014020032,
#   '/api/v1/game/2014020032/feed/live',
#   20142015,
#   '2014-10-12T02:00:00Z',
#   '02',
#   52,
#   28),
#  (2014020033,
#   '/api/v1/game/2014020033/feed/live',
#   20142015,
#   '2014-10-12T23:00:00Z',
#   '02',
#   10,
#   3),
#  (2014020034,
#   '/api/v1/game/2014020034/feed/live',
#   20142015,
#   '2014-10-13T02:00:00Z',
#   '02',
#   52,
#   26),
#  (2014020035,
#   '/api/v1/game/2014020035/feed/live',
#   20142015,
#   '2014-10-13T17:00:00Z',
#   '02',
#   21,
#   6),
#  (2014020036,
#   '/api/v1/game/2014020036/feed/live',
#   20142015,
#   '2014-10-13T19:00:00Z',
#   '02',
#   24,
#   7),
#  (2014020037,
#   '/api/v1/game/2014020037/feed/live',
#   20142015,
#   '2014-10-13T23:30:00Z',
#   '02',
#   9,
#   13),
#  (2014021194,
#   '/api/v1/game/2014021194/feed/live',
#   20142015,
#   '2014-10-13T23:30:00Z',
#   '02',
#   8,
#   14),
#  (2014020038,
#   '/api/v1/game/2014020038/feed/live',
#   20142015,
#   '2014-10-14T23:00:00Z',
#   '02',
#   2,
#   3),
#  (2014020039,
#   '/api/v1/game/2014020039/feed/live',
#   20142015,
#   '2014-10-14T23:00:00Z',
#   '02',
#   24,
#   4),
#  (2014020040,
#   '/api/v1/game/2014020040/feed/live',
#   20142015,
#   '2014-10-14T23:00:00Z',
#   '02',
#   28,
#   15),
#  (2014020042,
#   '/api/v1/game/2014020042/feed/live',
#   20142015,
#   '2014-10-14T23:00:00Z',
#   '02',
#   25,
#   29),
#  (2014020041,
#   '/api/v1/game/2014020041/feed/live',
#   20142015,
#   '2014-10-14T23:30:00Z',
#   '02',
#   7,
#   12),
#  (2014020043,
#   '/api/v1/game/2014020043/feed/live',
#   20142015,
#   '2014-10-14T23:30:00Z',
#   '02',
#   21,
#   10),
#  (2014020044,
#   '/api/v1/game/2014020044/feed/live',
#   20142015,
#   '2014-10-14T23:30:00Z',
#   '02',
#   1,
#   14),
#  (2014020045,
#   '/api/v1/game/2014020045/feed/live',
#   20142015,
#   '2014-10-15T00:00:00Z',
#   '02',
#   20,
#   18),
#  (2014020046,
#   '/api/v1/game/2014020046/feed/live',
#   20142015,
#   '2014-10-15T02:30:00Z',
#   '02',
#   22,
#   26),
#  (2014020048,
#   '/api/v1/game/2014020048/feed/live',
#   20142015,
#   '2014-10-16T00:00:00Z',
#   '02',
#   20,
#   16),
#  (2014020047,
#   '/api/v1/game/2014020047/feed/live',
#   20142015,
#   '2014-10-16T00:00:00Z',
#   '02',
#   6,
#   17),
#  (2014020049,
#   '/api/v1/game/2014020049/feed/live',
#   20142015,
#   '2014-10-16T02:30:00Z',
#   '02',
#   22,
#   53),
#  (2014020050,
#   '/api/v1/game/2014020050/feed/live',
#   20142015,
#   '2014-10-16T23:00:00Z',
#   '02',
#   28,
#   2),
#  (2014020051,
#   '/api/v1/game/2014020051/feed/live',
#   20142015,
#   '2014-10-16T23:00:00Z',
#   '02',
#   25,
#   5),
#  (2014020052,
#   '/api/v1/game/2014020052/feed/live',
#   20142015,
#   '2014-10-16T23:00:00Z',
#   '02',
#   1,
#   15),
#  (2014020057,
#   '/api/v1/game/2014020057/feed/live',
#   20142015,
#   '2014-10-16T23:00:00Z',
#   '02',
#   12,
#   3),
#  (2014020053,
#   '/api/v1/game/2014020053/feed/live',
#   20142015,
#   '2014-10-16T23:30:00Z',
#   '02',
#   6,
#   8),
#  (2014020054,
#   '/api/v1/game/2014020054/feed/live',
#   20142015,
#   '2014-10-16T23:30:00Z',
#   '02',
#   21,
#   9),
#  (2014020055,
#   '/api/v1/game/2014020055/feed/live',
#   20142015,
#   '2014-10-17T02:30:00Z',
#   '02',
#   19,
#   26),
#  (2014020056,
#   '/api/v1/game/2014020056/feed/live',
#   20142015,
#   '2014-10-17T23:00:00Z',
#   '02',
#   13,
#   7),
#  (2014020058,
#   '/api/v1/game/2014020058/feed/live',
#   20142015,
#   '2014-10-17T23:00:00Z',
#   '02',
#   20,
#   29),
#  (2014020059,
#   '/api/v1/game/2014020059/feed/live',
#   20142015,
#   '2014-10-17T23:30:00Z',
#   '02',
#   17,
#   10),
#  (2014020060,
#   '/api/v1/game/2014020060/feed/live',
#   20142015,
#   '2014-10-18T00:00:00Z',
#   '02',
#   18,
#   52),
#  (2014020061,
#   '/api/v1/game/2014020061/feed/live',
#   20142015,
#   '2014-10-18T01:30:00Z',
#   '02',
#   23,
#   22),
#  (2014020062,
#   '/api/v1/game/2014020062/feed/live',
#   20142015,
#   '2014-10-18T02:00:00Z',
#   '02',
#   30,
#   24),
#  (2014020063,
#   '/api/v1/game/2014020063/feed/live',
#   20142015,
#   '2014-10-18T23:00:00Z',
#   '02',
#   6,
#   7),
#  (2014020064,
#   '/api/v1/game/2014020064/feed/live',
#   20142015,
#   '2014-10-18T23:00:00Z',
#   '02',
#   21,
#   8),
#  (2014020065,
#   '/api/v1/game/2014020065/feed/live',
#   20142015,
#   '2014-10-18T23:00:00Z',
#   '02',
#   29,
#   9),
#  (2014020066,
#   '/api/v1/game/2014020066/feed/live',
#   20142015,
#   '2014-10-18T23:00:00Z',
#   '02',
#   10,
#   17),
#  (2014020067,
#   '/api/v1/game/2014020067/feed/live',
#   20142015,
#   '2014-10-18T23:00:00Z',
#   '02',
#   28,
#   1),
#  (2014020068,
#   '/api/v1/game/2014020068/feed/live',
#   20142015,
#   '2014-10-18T23:00:00Z',
#   '02',
#   2,
#   5),
#  (2014020069,
#   '/api/v1/game/2014020069/feed/live',
#   20142015,
#   '2014-10-18T23:00:00Z',
#   '02',
#   13,
#   15),
#  (2014020070,
#   '/api/v1/game/2014020070/feed/live',
#   20142015,
#   '2014-10-19T00:00:00Z',
#   '02',
#   4,
#   25),
#  (2014020071,
#   '/api/v1/game/2014020071/feed/live',
#   20142015,
#   '2014-10-19T00:30:00Z',
#   '02',
#   18,
#   16),
#  (2014020072,
#   '/api/v1/game/2014020072/feed/live',
#   20142015,
#   '2014-10-19T01:00:00Z',
#   '02',
#   19,
#   53),
#  (2014020073,
#   '/api/v1/game/2014020073/feed/live',
#   20142015,
#   '2014-10-19T02:00:00Z',
#   '02',
#   14,
#   23),
#  (2014020074,
#   '/api/v1/game/2014020074/feed/live',
#   20142015,
#   '2014-10-19T19:00:00Z',
#   '02',
#   30,
#   26),
#  (2014020075,
#   '/api/v1/game/2014020075/feed/live',
#   20142015,
#   '2014-10-19T21:00:00Z',
#   '02',
#   28,
#   3),
#  (2014020076,
#   '/api/v1/game/2014020076/feed/live',
#   20142015,
#   '2014-10-19T23:00:00Z',
#   '02',
#   20,
#   52),
#  (2014020077,
#   '/api/v1/game/2014020077/feed/live',
#   20142015,
#   '2014-10-20T00:00:00Z',
#   '02',
#   19,
#   24),
#  (2014020078,
#   '/api/v1/game/2014020078/feed/live',
#   20142015,
#   '2014-10-21T01:30:00Z',
#   '02',
#   14,
#   22),
#  (2014020079,
#   '/api/v1/game/2014020079/feed/live',
#   20142015,
#   '2014-10-21T23:00:00Z',
#   '02',
#   28,
#   6),
#  (2014020080,
#   '/api/v1/game/2014020080/feed/live',
#   20142015,
#   '2014-10-21T23:00:00Z',
#   '02',
#   3,
#   1),
#  (2014020081,
#   '/api/v1/game/2014020081/feed/live',
#   20142015,
#   '2014-10-21T23:00:00Z',
#   '02',
#   10,
#   2),
#  (2014020082,
#   '/api/v1/game/2014020082/feed/live',
#   20142015,
#   '2014-10-21T23:30:00Z',
#   '02',
#   17,
#   8),
#  (2014020083,
#   '/api/v1/game/2014020083/feed/live',
#   20142015,
#   '2014-10-22T00:00:00Z',
#   '02',
#   53,
#   18),
#  (2014020084,
#   '/api/v1/game/2014020084/feed/live',
#   20142015,
#   '2014-10-22T00:00:00Z',
#   '02',
#   12,
#   52),
#  (2014020085,
#   '/api/v1/game/2014020085/feed/live',
#   20142015,
#   '2014-10-22T00:30:00Z',
#   '02',
#   4,
#   16),
#  (2014020086,
#   '/api/v1/game/2014020086/feed/live',
#   20142015,
#   '2014-10-22T00:30:00Z',
#   '02',
#   23,
#   25),
#  (2014020087,
#   '/api/v1/game/2014020087/feed/live',
#   20142015,
#   '2014-10-22T01:00:00Z',
#   '02',
#   13,
#   21),
#  (2014020088,
#   '/api/v1/game/2014020088/feed/live',
#   20142015,
#   '2014-10-22T01:00:00Z',
#   '02',
#   14,
#   20),
#  (2014020090,
#   '/api/v1/game/2014020090/feed/live',
#   20142015,
#   '2014-10-23T00:00:00Z',
#   '02',
#   4,
#   5),
#  (2014020091,
#   '/api/v1/game/2014020091/feed/live',
#   20142015,
#   '2014-10-23T01:30:00Z',
#   '02',
#   15,
#   22),
#  (2014020092,
#   '/api/v1/game/2014020092/feed/live',
#   20142015,
#   '2014-10-23T02:30:00Z',
#   '02',
#   7,
#   24),
#  (2014020093,
#   '/api/v1/game/2014020093/feed/live',
#   20142015,
#   '2014-10-23T23:00:00Z',
#   '02',
#   2,
#   6),
#  (2014020094,
#   '/api/v1/game/2014020094/feed/live',
#   20142015,
#   '2014-10-23T23:30:00Z',
#   '02',
#   5,
#   17),
#  (2014020095,
#   '/api/v1/game/2014020095/feed/live',
#   20142015,
#   '2014-10-24T00:00:00Z',
#   '02',
#   23,
#   19),
#  (2014020096,
#   '/api/v1/game/2014020096/feed/live',
#   20142015,
#   '2014-10-24T00:00:00Z',
#   '02',
#   16,
#   18),
#  (2014020097,
#   '/api/v1/game/2014020097/feed/live',
#   20142015,
#   '2014-10-24T00:00:00Z',
#   '02',
#   53,
#   30),
#  (2014020098,
#   '/api/v1/game/2014020098/feed/live',
#   20142015,
#   '2014-10-24T01:00:00Z',
#   '02',
#   12,
#   20),
#  (2014020099,
#   '/api/v1/game/2014020099/feed/live',
#   20142015,
#   '2014-10-24T02:30:00Z',
#   '02',
#   7,
#   26),
#  (2014020100,
#   '/api/v1/game/2014020100/feed/live',
#   20142015,
#   '2014-10-24T02:30:00Z',
#   '02',
#   29,
#   28),
#  (2014020101,
#   '/api/v1/game/2014020101/feed/live',
#   20142015,
#   '2014-10-24T23:00:00Z',
#   '02',
#   25,
#   1),
#  (2014020102,
#   '/api/v1/game/2014020102/feed/live',
#   20142015,
#   '2014-10-25T00:00:00Z',
#   '02',
#   14,
#   52),
#  (2014020103,
#   '/api/v1/game/2014020103/feed/live',
#   20142015,
#   '2014-10-25T01:00:00Z',
#   '02',
#   23,
#   21),
#  (2014020104,
#   '/api/v1/game/2014020104/feed/live',
#   20142015,
#   '2014-10-25T01:30:00Z',
#   '02',
#   12,
#   22),
#  (2014020105,
#   '/api/v1/game/2014020105/feed/live',
#   20142015,
#   '2014-10-25T02:00:00Z',
#   '02',
#   29,
#   24),
#  (2014020106,
#   '/api/v1/game/2014020106/feed/live',
#   20142015,
#   '2014-10-25T20:00:00Z',
#   '02',
#   7,
#   28),
#  (2014020107,
#   '/api/v1/game/2014020107/feed/live',
#   20142015,
#   '2014-10-25T23:00:00Z',
#   '02',
#   6,
#   10),
#  (2014020108,
#   '/api/v1/game/2014020108/feed/live',
#   20142015,
#   '2014-10-25T23:00:00Z',
#   '02',
#   3,
#   8),
#  (2014020109,
#   '/api/v1/game/2014020109/feed/live',
#   20142015,
#   '2014-10-25T23:00:00Z',
#   '02',
#   1,
#   9),
#  (2014020110,
#   '/api/v1/game/2014020110/feed/live',
#   20142015,
#   '2014-10-25T23:00:00Z',
#   '02',
#   25,
#   2),
#  (2014020111,
#   '/api/v1/game/2014020111/feed/live',
#   20142015,
#   '2014-10-25T23:00:00Z',
#   '02',
#   17,
#   4),
#  (2014020112,
#   '/api/v1/game/2014020112/feed/live',
#   20142015,
#   '2014-10-26T00:00:00Z',
#   '02',
#   16,
#   19),
#  (2014020113,
#   '/api/v1/game/2014020113/feed/live',
#   20142015,
#   '2014-10-26T00:00:00Z',
#   '02',
#   5,
#   18),
#  (2014020114,
#   '/api/v1/game/2014020114/feed/live',
#   20142015,
#   '2014-10-26T00:00:00Z',
#   '02',
#   14,
#   30),
#  (2014020115,
#   '/api/v1/game/2014020115/feed/live',
#   20142015,
#   '2014-10-26T01:00:00Z',
#   '02',
#   13,
#   53),
#  (2014020116,
#   '/api/v1/game/2014020116/feed/live',
#   20142015,
#   '2014-10-26T02:00:00Z',
#   '02',
#   15,
#   20),
#  (2014020117,
#   '/api/v1/game/2014020117/feed/live',
#   20142015,
#   '2014-10-26T19:00:00Z',
#   '02',
#   21,
#   52),
#  (2014020118,
#   '/api/v1/game/2014020118/feed/live',
#   20142015,
#   '2014-10-26T20:00:00Z',
#   '02',
#   29,
#   26),
#  (2014020119,
#   '/api/v1/game/2014020119/feed/live',
#   20142015,
#   '2014-10-26T23:00:00Z',
#   '02',
#   9,
#   16),
#  (2014020120,
#   '/api/v1/game/2014020120/feed/live',
#   20142015,
#   '2014-10-27T00:00:00Z',
#   '02',
#   28,
#   24),
#  (2014020121,
#   '/api/v1/game/2014020121/feed/live',
#   20142015,
#   '2014-10-27T01:30:00Z',
#   '02',
#   15,
#   23),
#  (2014020122,
#   '/api/v1/game/2014020122/feed/live',
#   20142015,
#   '2014-10-27T23:00:00Z',
#   '02',
#   30,
#   3),
#  (2014020123,
#   '/api/v1/game/2014020123/feed/live',
#   20142015,
#   '2014-10-28T01:30:00Z',
#   '02',
#   8,
#   22),
#  (2014020124,
#   '/api/v1/game/2014020124/feed/live',
#   20142015,
#   '2014-10-28T23:00:00Z',
#   '02',
#   30,
#   6),
#  (2014020125,
#   '/api/v1/game/2014020125/feed/live',
#   20142015,
#   '2014-10-28T23:00:00Z',
#   '02',
#   52,
#   2),
#  (2014020126,
#   '/api/v1/game/2014020126/feed/live',
#   20142015,
#   '2014-10-28T23:00:00Z',
#   '02',
#   26,
#   4),
#  (2014020127,
#   '/api/v1/game/2014020127/feed/live',
#   20142015,
#   '2014-10-28T23:00:00Z',
#   '02',
#   1,
#   5),
#  (2014020128,
#   '/api/v1/game/2014020128/feed/live',
#   20142015,
#   '2014-10-28T23:00:00Z',
#   '02',
#   9,
#   29),
#  (2014020129,
#   '/api/v1/game/2014020129/feed/live',
#   20142015,
#   '2014-10-28T23:30:00Z',
#   '02',
#   7,
#   10),
#  (2014020130,
#   '/api/v1/game/2014020130/feed/live',
#   20142015,
#   '2014-10-28T23:30:00Z',
#   '02',
#   53,
#   14),
#  (2014020131,
#   '/api/v1/game/2014020131/feed/live',
#   20142015,
#   '2014-10-29T00:30:00Z',
#   '02',
#   24,
#   16),
#  (2014020132,
#   '/api/v1/game/2014020132/feed/live',
#   20142015,
#   '2014-10-29T00:30:00Z',
#   '02',
#   19,
#   25),
#  (2014020133,
#   '/api/v1/game/2014020133/feed/live',
#   20142015,
#   '2014-10-29T01:00:00Z',
#   '02',
#   28,
#   21),
#  (2014020134,
#   '/api/v1/game/2014020134/feed/live',
#   20142015,
#   '2014-10-29T01:00:00Z',
#   '02',
#   8,
#   20),
#  (2014020135,
#   '/api/v1/game/2014020135/feed/live',
#   20142015,
#   '2014-10-29T02:00:00Z',
#   '02',
#   12,
#   23),
#  (2014020136,
#   '/api/v1/game/2014020136/feed/live',
#   20142015,
#   '2014-10-29T23:30:00Z',
#   '02',
#   17,
#   15),
#  (2014020137,
#   '/api/v1/game/2014020137/feed/live',
#   20142015,
#   '2014-10-30T02:00:00Z',
#   '02',
#   18,
#   22),
#  (2014020138,
#   '/api/v1/game/2014020138/feed/live',
#   20142015,
#   '2014-10-30T23:00:00Z',
#   '02',
#   6,
#   7),
#  (2014020139,
#   '/api/v1/game/2014020139/feed/live',
#   20142015,
#   '2014-10-30T23:00:00Z',
#   '02',
#   52,
#   1),
#  (2014020140,
#   '/api/v1/game/2014020140/feed/live',
#   20142015,
#   '2014-10-30T23:00:00Z',
#   '02',
#   26,
#   5),
#  (2014020141,
#   '/api/v1/game/2014020141/feed/live',
#   20142015,
#   '2014-10-30T23:30:00Z',
#   '02',
#   16,
#   9),
#  (2014020142,
#   '/api/v1/game/2014020142/feed/live',
#   20142015,
#   '2014-10-30T23:30:00Z',
#   '02',
#   4,
#   14),
#  (2014020143,
#   '/api/v1/game/2014020143/feed/live',
#   20142015,
#   '2014-10-30T23:30:00Z',
#   '02',
#   53,
#   13),
#  (2014020144,
#   '/api/v1/game/2014020144/feed/live',
#   20142015,
#   '2014-10-31T00:00:00Z',
#   '02',
#   24,
#   19),
#  (2014020145,
#   '/api/v1/game/2014020145/feed/live',
#   20142015,
#   '2014-10-31T00:00:00Z',
#   '02',
#   28,
#   30),
#  (2014020146,
#   '/api/v1/game/2014020146/feed/live',
#   20142015,
#   '2014-10-31T01:00:00Z',
#   '02',
#   2,
#   21),
#  (2014020147,
#   '/api/v1/game/2014020147/feed/live',
#   20142015,
#   '2014-10-31T02:00:00Z',
#   '02',
#   8,
#   23),
#  (2014020148,
#   '/api/v1/game/2014020148/feed/live',
#   20142015,
#   '2014-10-31T23:00:00Z',
#   '02',
#   10,
#   29),
#  (2014020149,
#   '/api/v1/game/2014020149/feed/live',
#   20142015,
#   '2014-10-31T23:30:00Z',
#   '02',
#   26,
#   17),
#  (2014020150,
#   '/api/v1/game/2014020150/feed/live',
#   20142015,
#   '2014-11-01T00:30:00Z',
#   '02',
#   24,
#   25),
#  (2014020151,
#   '/api/v1/game/2014020151/feed/live',
#   20142015,
#   '2014-11-01T01:00:00Z',
#   '02',
#   18,
#   20),
#  (2014020153,
#   '/api/v1/game/2014020153/feed/live',
#   20142015,
#   '2014-11-01T23:00:00Z',
#   '02',
#   9,
#   6),
#  (2014020154,
#   '/api/v1/game/2014020154/feed/live',
#   20142015,
#   '2014-11-01T23:00:00Z',
#   '02',
#   16,
#   10),
#  (2014020155,
#   '/api/v1/game/2014020155/feed/live',
#   20142015,
#   '2014-11-01T23:00:00Z',
#   '02',
#   15,
#   14),
#  (2014020156,
#   '/api/v1/game/2014020156/feed/live',
#   20142015,
#   '2014-11-01T23:00:00Z',
#   '02',
#   4,
#   13),
#  (2014020157,
#   '/api/v1/game/2014020157/feed/live',
#   20142015,
#   '2014-11-01T23:00:00Z',
#   '02',
#   29,
#   1),
#  (2014020158,
#   '/api/v1/game/2014020158/feed/live',
#   20142015,
#   '2014-11-01T23:00:00Z',
#   '02',
#   52,
#   3),
#  (2014020159,
#   '/api/v1/game/2014020159/feed/live',
#   20142015,
#   '2014-11-01T23:00:00Z',
#   '02',
#   7,
#   5),
#  (2014020160,
#   '/api/v1/game/2014020160/feed/live',
#   20142015,
#   '2014-11-01T23:00:00Z',
#   '02',
#   53,
#   12),
#  (2014020161,
#   '/api/v1/game/2014020161/feed/live',
#   20142015,
#   '2014-11-02T00:00:00Z',
#   '02',
#   21,
#   19),
#  (2014020162,
#   '/api/v1/game/2014020162/feed/live',
#   20142015,
#   '2014-11-02T00:00:00Z',
#   '02',
#   25,
#   30),
#  (2014020163,
#   '/api/v1/game/2014020163/feed/live',
#   20142015,
#   '2014-11-02T02:00:00Z',
#   '02',
#   23,
#   22),
#  (2014020152,
#   '/api/v1/game/2014020152/feed/live',
#   20142015,
#   '2014-11-02T02:30:00Z',
#   '02',
#   2,
#   28),
#  (2014020164,
#   '/api/v1/game/2014020164/feed/live',
#   20142015,
#   '2014-11-02T22:00:00Z',
#   '02',
#   17,
#   7),
#  (2014020165,
#   '/api/v1/game/2014020165/feed/live',
#   20142015,
#   '2014-11-02T22:00:00Z',
#   '02',
#   26,
#   12),
#  (2014020166,
#   '/api/v1/game/2014020166/feed/live',
#   20142015,
#   '2014-11-03T00:00:00Z',
#   '02',
#   20,
#   8),
#  (2014020167,
#   '/api/v1/game/2014020167/feed/live',
#   20142015,
#   '2014-11-03T00:00:00Z',
#   '02',
#   53,
#   15),
#  (2014020168,
#   '/api/v1/game/2014020168/feed/live',
#   20142015,
#   '2014-11-03T01:00:00Z',
#   '02',
#   24,
#   21),
#  (2014020169,
#   '/api/v1/game/2014020169/feed/live',
#   20142015,
#   '2014-11-03T02:00:00Z',
#   '02',
#   52,
#   16),
#  (2014020170,
#   '/api/v1/game/2014020170/feed/live',
#   20142015,
#   '2014-11-03T02:30:00Z',
#   '02',
#   18,
#   23),
#  (2014020171,
#   '/api/v1/game/2014020171/feed/live',
#   20142015,
#   '2014-11-04T00:00:00Z',
#   '02',
#   19,
#   3),
#  (2014020172,
#   '/api/v1/game/2014020172/feed/live',
#   20142015,
#   '2014-11-05T00:00:00Z',
#   '02',
#   13,
#   6),
#  (2014020174,
#   '/api/v1/game/2014020174/feed/live',
#   20142015,
#   '2014-11-05T00:00:00Z',
#   '02',
#   22,
#   4),
#  (2014020175,
#   '/api/v1/game/2014020175/feed/live',
#   20142015,
#   '2014-11-05T00:00:00Z',
#   '02',
#   20,
#   15),
#  (2014020176,
#   '/api/v1/game/2014020176/feed/live',
#   20142015,
#   '2014-11-05T00:00:00Z',
#   '02',
#   12,
#   29),
#  (2014020173,
#   '/api/v1/game/2014020173/feed/live',
#   20142015,
#   '2014-11-05T00:30:00Z',
#   '02',
#   19,
#   1),
#  (2014020177,
#   '/api/v1/game/2014020177/feed/live',
#   20142015,
#   '2014-11-05T00:30:00Z',
#   '02',
#   16,
#   8),
#  (2014020178,
#   '/api/v1/game/2014020178/feed/live',
#   20142015,
#   '2014-11-05T00:30:00Z',
#   '02',
#   17,
#   9),
#  (2014020179,
#   '/api/v1/game/2014020179/feed/live',
#   20142015,
#   '2014-11-05T01:00:00Z',
#   '02',
#   5,
#   30),
#  (2014020180,
#   '/api/v1/game/2014020180/feed/live',
#   20142015,
#   '2014-11-05T01:00:00Z',
#   '02',
#   18,
#   52),
#  (2014020181,
#   '/api/v1/game/2014020181/feed/live',
#   20142015,
#   '2014-11-05T01:30:00Z',
#   '02',
#   26,
#   25),
#  (2014020182,
#   '/api/v1/game/2014020182/feed/live',
#   20142015,
#   '2014-11-05T02:00:00Z',
#   '02',
#   23,
#   21),
#  (2014020183,
#   '/api/v1/game/2014020183/feed/live',
#   20142015,
#   '2014-11-05T02:00:00Z',
#   '02',
#   10,
#   53),
#  (2014020184,
#   '/api/v1/game/2014020184/feed/live',
#   20142015,
#   '2014-11-06T00:30:00Z',
#   '02',
#   8,
#   7),
#  (2014020185,
#   '/api/v1/game/2014020185/feed/live',
#   20142015,
#   '2014-11-06T01:00:00Z',
#   '02',
#   17,
#   3),
#  (2014020186,
#   '/api/v1/game/2014020186/feed/live',
#   20142015,
#   '2014-11-06T03:30:00Z',
#   '02',
#   2,
#   24),
#  (2014020187,
#   '/api/v1/game/2014020187/feed/live',
#   20142015,
#   '2014-11-07T00:00:00Z',
#   '02',
#   22,
#   6),
#  (2014020188,
#   '/api/v1/game/2014020188/feed/live',
#   20142015,
#   '2014-11-07T00:00:00Z',
#   '02',
#   13,
#   4),
#  (2014020189,
#   '/api/v1/game/2014020189/feed/live',
#   20142015,
#   '2014-11-07T00:30:00Z',
#   '02',
#   30,
#   9),
#  (2014020190,
#   '/api/v1/game/2014020190/feed/live',
#   20142015,
#   '2014-11-07T00:30:00Z',
#   '02',
#   20,
#   14),
#  (2014020191,
#   '/api/v1/game/2014020191/feed/live',
#   20142015,
#   '2014-11-07T01:00:00Z',
#   '02',
#   1,
#   19),
#  (2014020192,
#   '/api/v1/game/2014020192/feed/live',
#   20142015,
#   '2014-11-07T01:00:00Z',
#   '02',
#   5,
#   52),
#  (2014020193,
#   '/api/v1/game/2014020193/feed/live',
#   20142015,
#   '2014-11-07T01:30:00Z',
#   '02',
#   18,
#   25),
#  (2014020194,
#   '/api/v1/game/2014020194/feed/live',
#   20142015,
#   '2014-11-07T02:00:00Z',
#   '02',
#   10,
#   21),
#  (2014020195,
#   '/api/v1/game/2014020195/feed/live',
#   20142015,
#   '2014-11-07T03:30:00Z',
#   '02',
#   2,
#   26),
#  (2014020196,
#   '/api/v1/game/2014020196/feed/live',
#   20142015,
#   '2014-11-07T03:30:00Z',
#   '02',
#   23,
#   28),
#  (2014020197,
#   '/api/v1/game/2014020197/feed/live',
#   20142015,
#   '2014-11-08T00:00:00Z',
#   '02',
#   22,
#   7),
#  (2014020198,
#   '/api/v1/game/2014020198/feed/live',
#   20142015,
#   '2014-11-08T00:00:00Z',
#   '02',
#   29,
#   12),
#  (2014020199,
#   '/api/v1/game/2014020199/feed/live',
#   20142015,
#   '2014-11-08T00:30:00Z',
#   '02',
#   1,
#   17),
#  (2014020200,
#   '/api/v1/game/2014020200/feed/live',
#   20142015,
#   '2014-11-08T01:30:00Z',
#   '02',
#   15,
#   16),
#  (2014020201,
#   '/api/v1/game/2014020201/feed/live',
#   20142015,
#   '2014-11-08T03:00:00Z',
#   '02',
#   53,
#   24),
#  (2014020202,
#   '/api/v1/game/2014020202/feed/live',
#   20142015,
#   '2014-11-08T20:00:00Z',
#   '02',
#   20,
#   13),
#  (2014020203,
#   '/api/v1/game/2014020203/feed/live',
#   20142015,
#   '2014-11-09T00:00:00Z',
#   '02',
#   5,
#   7),
#  (2014020204,
#   '/api/v1/game/2014020204/feed/live',
#   20142015,
#   '2014-11-09T00:00:00Z',
#   '02',
#   3,
#   10),
#  (2014020205,
#   '/api/v1/game/2014020205/feed/live',
#   20142015,
#   '2014-11-09T00:00:00Z',
#   '02',
#   30,
#   8),
#  (2014020206,
#   '/api/v1/game/2014020206/feed/live',
#   20142015,
#   '2014-11-09T00:00:00Z',
#   '02',
#   52,
#   9),
#  (2014020207,
#   '/api/v1/game/2014020207/feed/live',
#   20142015,
#   '2014-11-09T00:00:00Z',
#   '02',
#   21,
#   4),
#  (2014020208,
#   '/api/v1/game/2014020208/feed/live',
#   20142015,
#   '2014-11-09T00:00:00Z',
#   '02',
#   14,
#   29),
#  (2014020212,
#   '/api/v1/game/2014020212/feed/live',
#   20142015,
#   '2014-11-09T01:00:00Z',
#   '02',
#   2,
#   53),
#  (2014020210,
#   '/api/v1/game/2014020210/feed/live',
#   20142015,
#   '2014-11-09T01:00:00Z',
#   '02',
#   18,
#   19),
#  (2014020211,
#   '/api/v1/game/2014020211/feed/live',
#   20142015,
#   '2014-11-09T01:00:00Z',
#   '02',
#   28,
#   25),
#  (2014020209,
#   '/api/v1/game/2014020209/feed/live',
#   20142015,
#   '2014-11-09T01:00:00Z',
#   '02',
#   12,
#   15),
#  (2014020213,
#   '/api/v1/game/2014020213/feed/live',
#   20142015,
#   '2014-11-09T03:00:00Z',
#   '02',
#   23,
#   26),
#  (2014020089,
#   '/api/v1/game/2014020089/feed/live',
#   20142015,
#   '2014-11-09T23:00:00Z',
#   '02',
#   10,
#   9),
#  (2014020214,
#   '/api/v1/game/2014020214/feed/live',
#   20142015,
#   '2014-11-09T23:00:00Z',
#   '02',
#   14,
#   17),
#  (2014020215,
#   '/api/v1/game/2014020215/feed/live',
#   20142015,
#   '2014-11-09T23:00:00Z',
#   '02',
#   22,
#   3),
#  (2014020216,
#   '/api/v1/game/2014020216/feed/live',
#   20142015,
#   '2014-11-10T00:00:00Z',
#   '02',
#   28,
#   16),
#  (2014020217,
#   '/api/v1/game/2014020217/feed/live',
#   20142015,
#   '2014-11-10T02:00:00Z',
#   '02',
#   23,
#   24),
#  (2014020218,
#   '/api/v1/game/2014020218/feed/live',
#   20142015,
#   '2014-11-11T00:00:00Z',
#   '02',
#   1,
#   6),
#  (2014020219,
#   '/api/v1/game/2014020219/feed/live',
#   20142015,
#   '2014-11-11T00:00:00Z',
#   '02',
#   20,
#   12),
#  (2014020220,
#   '/api/v1/game/2014020220/feed/live',
#   20142015,
#   '2014-11-12T00:00:00Z',
#   '02',
#   30,
#   1),
#  (2014020221,
#   '/api/v1/game/2014020221/feed/live',
#   20142015,
#   '2014-11-12T00:00:00Z',
#   '02',
#   21,
#   2),
#  (2014020222,
#   '/api/v1/game/2014020222/feed/live',
#   20142015,
#   '2014-11-12T00:00:00Z',
#   '02',
#   5,
#   3),
#  (2014020223,
#   '/api/v1/game/2014020223/feed/live',
#   20142015,
#   '2014-11-12T00:00:00Z',
#   '02',
#   29,
#   15),
#  (2014020224,
#   '/api/v1/game/2014020224/feed/live',
#   20142015,
#   '2014-11-12T00:30:00Z',
#   '02',
#   52,
#   8),
#  (2014020225,
#   '/api/v1/game/2014020225/feed/live',
#   20142015,
#   '2014-11-12T00:30:00Z',
#   '02',
#   28,
#   13),
#  (2014020226,
#   '/api/v1/game/2014020226/feed/live',
#   20142015,
#   '2014-11-12T01:00:00Z',
#   '02',
#   7,
#   19),
#  (2014020227,
#   '/api/v1/game/2014020227/feed/live',
#   20142015,
#   '2014-11-12T01:00:00Z',
#   '02',
#   22,
#   18),
#  (2014020228,
#   '/api/v1/game/2014020228/feed/live',
#   20142015,
#   '2014-11-12T01:30:00Z',
#   '02',
#   14,
#   16),
#  (2014020229,
#   '/api/v1/game/2014020229/feed/live',
#   20142015,
#   '2014-11-12T02:00:00Z',
#   '02',
#   25,
#   53),
#  (2014020230,
#   '/api/v1/game/2014020230/feed/live',
#   20142015,
#   '2014-11-12T03:00:00Z',
#   '02',
#   9,
#   23),
#  (2014020231,
#   '/api/v1/game/2014020231/feed/live',
#   20142015,
#   '2014-11-13T01:00:00Z',
#   '02',
#   6,
#   10),
#  (2014020232,
#   '/api/v1/game/2014020232/feed/live',
#   20142015,
#   '2014-11-13T03:30:00Z',
#   '02',
#   26,
#   24),
#  (2014020233,
#   '/api/v1/game/2014020233/feed/live',
#   20142015,
#   '2014-11-14T00:00:00Z',
#   '02',
#   21,
#   3),
#  (2014020234,
#   '/api/v1/game/2014020234/feed/live',
#   20142015,
#   '2014-11-14T00:00:00Z',
#   '02',
#   52,
#   12),
#  (2014020235,
#   '/api/v1/game/2014020235/feed/live',
#   20142015,
#   '2014-11-14T00:30:00Z',
#   '02',
#   6,
#   8),
#  (2014020236,
#   '/api/v1/game/2014020236/feed/live',
#   20142015,
#   '2014-11-14T00:30:00Z',
#   '02',
#   28,
#   14),
#  (2014020237,
#   '/api/v1/game/2014020237/feed/live',
#   20142015,
#   '2014-11-14T01:00:00Z',
#   '02',
#   18,
#   19),
#  (2014020238,
#   '/api/v1/game/2014020238/feed/live',
#   20142015,
#   '2014-11-14T01:00:00Z',
#   '02',
#   7,
#   30),
#  (2014020239,
#   '/api/v1/game/2014020239/feed/live',
#   20142015,
#   '2014-11-14T02:00:00Z',
#   '02',
#   53,
#   20),
#  (2014020240,
#   '/api/v1/game/2014020240/feed/live',
#   20142015,
#   '2014-11-14T02:30:00Z',
#   '02',
#   9,
#   22),
#  (2014020241,
#   '/api/v1/game/2014020241/feed/live',
#   20142015,
#   '2014-11-14T03:30:00Z',
#   '02',
#   25,
#   26),
#  (2014020242,
#   '/api/v1/game/2014020242/feed/live',
#   20142015,
#   '2014-11-15T00:00:00Z',
#   '02',
#   29,
#   4),
#  (2014020243,
#   '/api/v1/game/2014020243/feed/live',
#   20142015,
#   '2014-11-15T00:00:00Z',
#   '02',
#   1,
#   15),
#  (2014020244,
#   '/api/v1/game/2014020244/feed/live',
#   20142015,
#   '2014-11-15T00:30:00Z',
#   '02',
#   5,
#   10),
#  (2014020245,
#   '/api/v1/game/2014020245/feed/live',
#   20142015,
#   '2014-11-15T00:30:00Z',
#   '02',
#   16,
#   17),
#  (2014020246,
#   '/api/v1/game/2014020246/feed/live',
#   20142015,
#   '2014-11-15T00:30:00Z',
#   '02',
#   2,
#   13),
#  (2014020247,
#   '/api/v1/game/2014020247/feed/live',
#   20142015,
#   '2014-11-15T03:00:00Z',
#   '02',
#   53,
#   23),
#  (2014020248,
#   '/api/v1/game/2014020248/feed/live',
#   20142015,
#   '2014-11-15T18:00:00Z',
#   '02',
#   12,
#   6),
#  (2014020249,
#   '/api/v1/game/2014020249/feed/live',
#   20142015,
#   '2014-11-15T19:00:00Z',
#   '02',
#   30,
#   25),
#  (2014020250,
#   '/api/v1/game/2014020250/feed/live',
#   20142015,
#   '2014-11-15T21:00:00Z',
#   '02',
#   24,
#   26),
#  (2014020257,
#   '/api/v1/game/2014020257/feed/live',
#   20142015,
#   '2014-11-16T00:00:00Z',
#   '02',
#   52,
#   18),
#  (2014020251,
#   '/api/v1/game/2014020251/feed/live',
#   20142015,
#   '2014-11-16T00:00:00Z',
#   '02',
#   10,
#   7),
#  (2014020252,
#   '/api/v1/game/2014020252/feed/live',
#   20142015,
#   '2014-11-16T00:00:00Z',
#   '02',
#   4,
#   8),
#  (2014020253,
#   '/api/v1/game/2014020253/feed/live',
#   20142015,
#   '2014-11-16T00:00:00Z',
#   '02',
#   2,
#   14),
#  (2014020254,
#   '/api/v1/game/2014020254/feed/live',
#   20142015,
#   '2014-11-16T00:00:00Z',
#   '02',
#   21,
#   1),
#  (2014020255,
#   '/api/v1/game/2014020255/feed/live',
#   20142015,
#   '2014-11-16T00:00:00Z',
#   '02',
#   3,
#   5),
#  (2014020256,
#   '/api/v1/game/2014020256/feed/live',
#   20142015,
#   '2014-11-16T00:00:00Z',
#   '02',
#   28,
#   29),
#  (2014020258,
#   '/api/v1/game/2014020258/feed/live',
#   20142015,
#   '2014-11-16T01:00:00Z',
#   '02',
#   15,
#   19),
#  (2014020259,
#   '/api/v1/game/2014020259/feed/live',
#   20142015,
#   '2014-11-16T03:00:00Z',
#   '02',
#   9,
#   20),
#  (2014020261,
#   '/api/v1/game/2014020261/feed/live',
#   20142015,
#   '2014-11-16T22:00:00Z',
#   '02',
#   52,
#   30),
#  (2014020260,
#   '/api/v1/game/2014020260/feed/live',
#   20142015,
#   '2014-11-16T22:00:00Z',
#   '02',
#   28,
#   12),
#  (2014020263,
#   '/api/v1/game/2014020263/feed/live',
#   20142015,
#   '2014-11-17T00:00:00Z',
#   '02',
#   25,
#   16),
#  (2014020262,
#   '/api/v1/game/2014020262/feed/live',
#   20142015,
#   '2014-11-17T00:00:00Z',
#   '02',
#   8,
#   17),
#  (2014020264,
#   '/api/v1/game/2014020264/feed/live',
#   20142015,
#   '2014-11-17T01:00:00Z',
#   '02',
#   13,
#   24),
#  (2014020265,
#   '/api/v1/game/2014020265/feed/live',
#   20142015,
#   '2014-11-17T02:00:00Z',
#   '02',
#   53,
#   22),
#  (2014020266,
#   '/api/v1/game/2014020266/feed/live',
#   20142015,
#   '2014-11-18T00:00:00Z',
#   '02',
#   14,
#   3),
#  (2014020267,
#   '/api/v1/game/2014020267/feed/live',
#   20142015,
#   '2014-11-19T00:00:00Z',
#   '02',
#   19,
#   6),
#  (2014020269,
#   '/api/v1/game/2014020269/feed/live',
#   20142015,
#   '2014-11-19T00:00:00Z',
#   '02',
#   14,
#   2),
#  (2014020270,
#   '/api/v1/game/2014020270/feed/live',
#   20142015,
#   '2014-11-19T00:00:00Z',
#   '02',
#   17,
#   29),
#  (2014020268,
#   '/api/v1/game/2014020268/feed/live',
#   20142015,
#   '2014-11-19T00:30:00Z',
#   '02',
#   28,
#   7),
#  (2014020271,
#   '/api/v1/game/2014020271/feed/live',
#   20142015,
#   '2014-11-19T00:30:00Z',
#   '02',
#   18,
#   10),
#  (2014020272,
#   '/api/v1/game/2014020272/feed/live',
#   20142015,
#   '2014-11-19T00:30:00Z',
#   '02',
#   5,
#   8),
#  (2014020273,
#   '/api/v1/game/2014020273/feed/live',
#   20142015,
#   '2014-11-19T01:00:00Z',
#   '02',
#   1,
#   52),
#  (2014020274,
#   '/api/v1/game/2014020274/feed/live',
#   20142015,
#   '2014-11-19T01:30:00Z',
#   '02',
#   12,
#   25),
#  (2014020275,
#   '/api/v1/game/2014020275/feed/live',
#   20142015,
#   '2014-11-19T02:00:00Z',
#   '02',
#   24,
#   20),
#  (2014020276,
#   '/api/v1/game/2014020276/feed/live',
#   20142015,
#   '2014-11-19T02:00:00Z',
#   '02',
#   15,
#   53),
#  (2014020277,
#   '/api/v1/game/2014020277/feed/live',
#   20142015,
#   '2014-11-19T03:30:00Z',
#   '02',
#   13,
#   26),
#  (2014020279,
#   '/api/v1/game/2014020279/feed/live',
#   20142015,
#   '2014-11-20T01:00:00Z',
#   '02',
#   23,
#   22),
#  (2014020278,
#   '/api/v1/game/2014020278/feed/live',
#   20142015,
#   '2014-11-20T01:00:00Z',
#   '02',
#   4,
#   3),
#  (2014020280,
#   '/api/v1/game/2014020280/feed/live',
#   20142015,
#   '2014-11-21T00:00:00Z',
#   '02',
#   30,
#   4),
#  (2014020281,
#   '/api/v1/game/2014020281/feed/live',
#   20142015,
#   '2014-11-21T00:30:00Z',
#   '02',
#   14,
#   10),
#  (2014020282,
#   '/api/v1/game/2014020282/feed/live',
#   20142015,
#   '2014-11-21T00:30:00Z',
#   '02',
#   19,
#   8),
#  (2014020283,
#   '/api/v1/game/2014020283/feed/live',
#   20142015,
#   '2014-11-21T00:30:00Z',
#   '02',
#   18,
#   9),
#  (2014020284,
#   '/api/v1/game/2014020284/feed/live',
#   20142015,
#   '2014-11-21T01:00:00Z',
#   '02',
#   17,
#   52),
#  (2014020285,
#   '/api/v1/game/2014020285/feed/live',
#   20142015,
#   '2014-11-21T01:30:00Z',
#   '02',
#   53,
#   25),
#  (2014020286,
#   '/api/v1/game/2014020286/feed/live',
#   20142015,
#   '2014-11-21T02:00:00Z',
#   '02',
#   15,
#   21),
#  (2014020287,
#   '/api/v1/game/2014020287/feed/live',
#   20142015,
#   '2014-11-21T02:00:00Z',
#   '02',
#   16,
#   20),
#  (2014020288,
#   '/api/v1/game/2014020288/feed/live',
#   20142015,
#   '2014-11-21T03:00:00Z',
#   '02',
#   24,
#   23),
#  (2014020289,
#   '/api/v1/game/2014020289/feed/live',
#   20142015,
#   '2014-11-21T03:30:00Z',
#   '02',
#   12,
#   26),
#  (2014020290,
#   '/api/v1/game/2014020290/feed/live',
#   20142015,
#   '2014-11-21T03:30:00Z',
#   '02',
#   13,
#   28),
#  (2014020292,
#   '/api/v1/game/2014020292/feed/live',
#   20142015,
#   '2014-11-22T00:00:00Z',
#   '02',
#   2,
#   5),
#  (2014020293,
#   '/api/v1/game/2014020293/feed/live',
#   20142015,
#   '2014-11-22T00:00:00Z',
#   '02',
#   6,
#   29),
#  (2014020294,
#   '/api/v1/game/2014020294/feed/live',
#   20142015,
#   '2014-11-22T02:30:00Z',
#   '02',
#   1,
#   22),
#  (2014020295,
#   '/api/v1/game/2014020295/feed/live',
#   20142015,
#   '2014-11-22T20:00:00Z',
#   '02',
#   19,
#   9),
#  (2014020296,
#   '/api/v1/game/2014020296/feed/live',
#   20142015,
#   '2014-11-23T00:00:00Z',
#   '02',
#   8,
#   6),
#  (2014020297,
#   '/api/v1/game/2014020297/feed/live',
#   20142015,
#   '2014-11-23T00:00:00Z',
#   '02',
#   17,
#   10),
#  (2014020298,
#   '/api/v1/game/2014020298/feed/live',
#   20142015,
#   '2014-11-23T00:00:00Z',
#   '02',
#   30,
#   14),
#  (2014020299,
#   '/api/v1/game/2014020299/feed/live',
#   20142015,
#   '2014-11-23T00:00:00Z',
#   '02',
#   5,
#   2),
#  (2014020300,
#   '/api/v1/game/2014020300/feed/live',
#   20142015,
#   '2014-11-23T00:00:00Z',
#   '02',
#   29,
#   4),
#  (2014020301,
#   '/api/v1/game/2014020301/feed/live',
#   20142015,
#   '2014-11-23T00:00:00Z',
#   '02',
#   7,
#   15),
#  (2014020302,
#   '/api/v1/game/2014020302/feed/live',
#   20142015,
#   '2014-11-23T01:00:00Z',
#   '02',
#   13,
#   18),
#  (2014020303,
#   '/api/v1/game/2014020303/feed/live',
#   20142015,
#   '2014-11-23T01:00:00Z',
#   '02',
#   26,
#   25),
#  (2014020304,
#   '/api/v1/game/2014020304/feed/live',
#   20142015,
#   '2014-11-23T02:00:00Z',
#   '02',
#   12,
#   21),
#  (2014020305,
#   '/api/v1/game/2014020305/feed/live',
#   20142015,
#   '2014-11-23T03:00:00Z',
#   '02',
#   1,
#   20),
#  (2014020306,
#   '/api/v1/game/2014020306/feed/live',
#   20142015,
#   '2014-11-23T03:00:00Z',
#   '02',
#   16,
#   22),
#  (2014020307,
#   '/api/v1/game/2014020307/feed/live',
#   20142015,
#   '2014-11-23T03:30:00Z',
#   '02',
#   53,
#   28),
#  (2014020308,
#   '/api/v1/game/2014020308/feed/live',
#   20142015,
#   '2014-11-23T21:30:00Z',
#   '02',
#   19,
#   52),
#  (2014020309,
#   '/api/v1/game/2014020309/feed/live',
#   20142015,
#   '2014-11-24T00:00:00Z',
#   '02',
#   8,
#   3),
#  (2014020310,
#   '/api/v1/game/2014020310/feed/live',
#   20142015,
#   '2014-11-24T01:00:00Z',
#   '02',
#   53,
#   24),
#  (2014020311,
#   '/api/v1/game/2014020311/feed/live',
#   20142015,
#   '2014-11-24T02:30:00Z',
#   '02',
#   16,
#   23),
#  (2014020312,
#   '/api/v1/game/2014020312/feed/live',
#   20142015,
#   '2014-11-25T00:00:00Z',
#   '02',
#   5,
#   6),
#  (2014020313,
#   '/api/v1/game/2014020313/feed/live',
#   20142015,
#   '2014-11-25T00:00:00Z',
#   '02',
#   4,
#   2),
#  (2014020314,
#   '/api/v1/game/2014020314/feed/live',
#   20142015,
#   '2014-11-25T00:30:00Z',
#   '02',
#   9,
#   17),
#  (2014020315,
#   '/api/v1/game/2014020315/feed/live',
#   20142015,
#   '2014-11-25T00:30:00Z',
#   '02',
#   30,
#   13),
#  (2014020316,
#   '/api/v1/game/2014020316/feed/live',
#   20142015,
#   '2014-11-26T00:00:00Z',
#   '02',
#   52,
#   29),
#  (2014020317,
#   '/api/v1/game/2014020317/feed/live',
#   20142015,
#   '2014-11-26T01:00:00Z',
#   '02',
#   9,
#   19),
#  (2014020318,
#   '/api/v1/game/2014020318/feed/live',
#   20142015,
#   '2014-11-26T01:00:00Z',
#   '02',
#   26,
#   18),
#  (2014020319,
#   '/api/v1/game/2014020319/feed/live',
#   20142015,
#   '2014-11-26T01:30:00Z',
#   '02',
#   22,
#   25),
#  (2014020320,
#   '/api/v1/game/2014020320/feed/live',
#   20142015,
#   '2014-11-26T02:00:00Z',
#   '02',
#   21,
#   53),
#  (2014020321,
#   '/api/v1/game/2014020321/feed/live',
#   20142015,
#   '2014-11-26T03:00:00Z',
#   '02',
#   1,
#   23),
#  (2014020322,
#   '/api/v1/game/2014020322/feed/live',
#   20142015,
#   '2014-11-26T03:00:00Z',
#   '02',
#   20,
#   24),
#  (2014020323,
#   '/api/v1/game/2014020323/feed/live',
#   20142015,
#   '2014-11-27T00:00:00Z',
#   '02',
#   52,
#   7),
#  (2014020324,
#   '/api/v1/game/2014020324/feed/live',
#   20142015,
#   '2014-11-27T00:00:00Z',
#   '02',
#   15,
#   2),
#  (2014020325,
#   '/api/v1/game/2014020325/feed/live',
#   20142015,
#   '2014-11-27T00:30:00Z',
#   '02',
#   4,
#   17),
#  (2014020326,
#   '/api/v1/game/2014020326/feed/live',
#   20142015,
#   '2014-11-27T00:30:00Z',
#   '02',
#   3,
#   14),
#  (2014020327,
#   '/api/v1/game/2014020327/feed/live',
#   20142015,
#   '2014-11-27T00:30:00Z',
#   '02',
#   12,
#   13),
#  (2014020328,
#   '/api/v1/game/2014020328/feed/live',
#   20142015,
#   '2014-11-27T00:30:00Z',
#   '02',
#   10,
#   5),
#  (2014020329,
#   '/api/v1/game/2014020329/feed/live',
#   20142015,
#   '2014-11-27T01:00:00Z',
#   '02',
#   26,
#   30),
#  (2014020330,
#   '/api/v1/game/2014020330/feed/live',
#   20142015,
#   '2014-11-27T02:00:00Z',
#   '02',
#   16,
#   21),
#  (2014020331,
#   '/api/v1/game/2014020331/feed/live',
#   20142015,
#   '2014-11-27T03:30:00Z',
#   '02',
#   20,
#   28),
#  (2014020332,
#   '/api/v1/game/2014020332/feed/live',
#   20142015,
#   '2014-11-28T01:00:00Z',
#   '02',
#   22,
#   18),
#  (2014020333,
#   '/api/v1/game/2014020333/feed/live',
#   20142015,
#   '2014-11-28T18:00:00Z',
#   '02',
#   3,
#   4),
#  (2014020334,
#   '/api/v1/game/2014020334/feed/live',
#   20142015,
#   '2014-11-28T21:00:00Z',
#   '02',
#   16,
#   24),
#  (2014020335,
#   '/api/v1/game/2014020335/feed/live',
#   20142015,
#   '2014-11-28T22:00:00Z',
#   '02',
#   2,
#   15),
#  (2014020336,
#   '/api/v1/game/2014020336/feed/live',
#   20142015,
#   '2014-11-29T00:00:00Z',
#   '02',
#   52,
#   6),
#  (2014020337,
#   '/api/v1/game/2014020337/feed/live',
#   20142015,
#   '2014-11-29T00:00:00Z',
#   '02',
#   8,
#   7),
#  (2014020338,
#   '/api/v1/game/2014020338/feed/live',
#   20142015,
#   '2014-11-29T00:00:00Z',
#   '02',
#   17,
#   1),
#  (2014020339,
#   '/api/v1/game/2014020339/feed/live',
#   20142015,
#   '2014-11-29T00:00:00Z',
#   '02',
#   12,
#   5),
#  (2014020340,
#   '/api/v1/game/2014020340/feed/live',
#   20142015,
#   '2014-11-29T00:00:00Z',
#   '02',
#   23,
#   29),
#  (2014020341,
#   '/api/v1/game/2014020341/feed/live',
#   20142015,
#   '2014-11-29T00:30:00Z',
#   '02',
#   9,
#   13),
#  (2014020342,
#   '/api/v1/game/2014020342/feed/live',
#   20142015,
#   '2014-11-29T01:00:00Z',
#   '02',
#   22,
#   19),
#  (2014020343,
#   '/api/v1/game/2014020343/feed/live',
#   20142015,
#   '2014-11-29T01:30:00Z',
#   '02',
#   30,
#   25),
#  (2014020348,
#   '/api/v1/game/2014020348/feed/live',
#   20142015,
#   '2014-11-29T18:00:00Z',
#   '02',
#   4,
#   3),
#  (2014020344,
#   '/api/v1/game/2014020344/feed/live',
#   20142015,
#   '2014-11-30T00:00:00Z',
#   '02',
#   15,
#   10),
#  (2014020345,
#   '/api/v1/game/2014020345/feed/live',
#   20142015,
#   '2014-11-30T00:00:00Z',
#   '02',
#   7,
#   8),
#  (2014020346,
#   '/api/v1/game/2014020346/feed/live',
#   20142015,
#   '2014-11-30T00:00:00Z',
#   '02',
#   9,
#   14),
#  (2014020347,
#   '/api/v1/game/2014020347/feed/live',
#   20142015,
#   '2014-11-30T00:00:00Z',
#   '02',
#   1,
#   2),
#  (2014020349,
#   '/api/v1/game/2014020349/feed/live',
#   20142015,
#   '2014-11-30T00:00:00Z',
#   '02',
#   5,
#   12),
#  (2014020350,
#   '/api/v1/game/2014020350/feed/live',
#   20142015,
#   '2014-11-30T01:00:00Z',
#   '02',
#   29,
#   18),
#  (2014020351,
#   '/api/v1/game/2014020351/feed/live',
#   20142015,
#   '2014-11-30T01:00:00Z',
#   '02',
#   19,
#   30),
#  (2014020352,
#   '/api/v1/game/2014020352/feed/live',
#   20142015,
#   '2014-11-30T02:00:00Z',
#   '02',
#   25,
#   21),
#  (2014020354,
#   '/api/v1/game/2014020354/feed/live',
#   20142015,
#   '2014-11-30T03:00:00Z',
#   '02',
#   16,
#   26),
#  (2014020353,
#   '/api/v1/game/2014020353/feed/live',
#   20142015,
#   '2014-11-30T03:00:00Z',
#   '02',
#   20,
#   53),
#  (2014020355,
#   '/api/v1/game/2014020355/feed/live',
#   20142015,
#   '2014-11-30T03:30:00Z',
#   '02',
#   24,
#   28),
#  (2014020356,
#   '/api/v1/game/2014020356/feed/live',
#   20142015,
#   '2014-11-30T19:00:00Z',
#   '02',
#   23,
#   17),
#  (2014020357,
#   '/api/v1/game/2014020357/feed/live',
#   20142015,
#   '2014-12-02T00:00:00Z',
#   '02',
#   14,
#   3),
#  (2014020358,
#   '/api/v1/game/2014020358/feed/live',
#   20142015,
#   '2014-12-02T00:00:00Z',
#   '02',
#   13,
#   29),
#  (2014020359,
#   '/api/v1/game/2014020359/feed/live',
#   20142015,
#   '2014-12-02T02:00:00Z',
#   '02',
#   8,
#   21),
#  (2014020360,
#   '/api/v1/game/2014020360/feed/live',
#   20142015,
#   '2014-12-02T02:30:00Z',
#   '02',
#   53,
#   22),
#  (2014020361,
#   '/api/v1/game/2014020361/feed/live',
#   20142015,
#   '2014-12-02T03:00:00Z',
#   '02',
#   6,
#   24),
#  (2014020363,
#   '/api/v1/game/2014020363/feed/live',
#   20142015,
#   '2014-12-03T00:00:00Z',
#   '02',
#   9,
#   2),
#  (2014020364,
#   '/api/v1/game/2014020364/feed/live',
#   20142015,
#   '2014-12-03T00:00:00Z',
#   '02',
#   1,
#   5),
#  (2014020365,
#   '/api/v1/game/2014020365/feed/live',
#   20142015,
#   '2014-12-03T00:00:00Z',
#   '02',
#   23,
#   15),
#  (2014020366,
#   '/api/v1/game/2014020366/feed/live',
#   20142015,
#   '2014-12-03T00:00:00Z',
#   '02',
#   18,
#   12),
#  (2014020362,
#   '/api/v1/game/2014020362/feed/live',
#   20142015,
#   '2014-12-03T00:30:00Z',
#   '02',
#   14,
#   7),
#  (2014020367,
#   '/api/v1/game/2014020367/feed/live',
#   20142015,
#   '2014-12-03T00:30:00Z',
#   '02',
#   25,
#   10),
#  (2014020368,
#   '/api/v1/game/2014020368/feed/live',
#   20142015,
#   '2014-12-03T00:30:00Z',
#   '02',
#   13,
#   17),
#  (2014020369,
#   '/api/v1/game/2014020369/feed/live',
#   20142015,
#   '2014-12-03T02:00:00Z',
#   '02',
#   53,
#   20),
#  (2014020370,
#   '/api/v1/game/2014020370/feed/live',
#   20142015,
#   '2014-12-03T03:00:00Z',
#   '02',
#   4,
#   28),
#  (2014020371,
#   '/api/v1/game/2014020371/feed/live',
#   20142015,
#   '2014-12-03T03:30:00Z',
#   '02',
#   6,
#   26),
#  (2014020372,
#   '/api/v1/game/2014020372/feed/live',
#   20142015,
#   '2014-12-04T00:00:00Z',
#   '02',
#   8,
#   30),
#  (2014020373,
#   '/api/v1/game/2014020373/feed/live',
#   20142015,
#   '2014-12-04T01:00:00Z',
#   '02',
#   19,
#   16),
#  (2014020374,
#   '/api/v1/game/2014020374/feed/live',
#   20142015,
#   '2014-12-04T02:00:00Z',
#   '02',
#   22,
#   52),
#  (2014020375,
#   '/api/v1/game/2014020375/feed/live',
#   20142015,
#   '2014-12-04T03:30:00Z',
#   '02',
#   4,
#   24),
#  (2014020376,
#   '/api/v1/game/2014020376/feed/live',
#   20142015,
#   '2014-12-05T00:00:00Z',
#   '02',
#   23,
#   5),
#  (2014020377,
#   '/api/v1/game/2014020377/feed/live',
#   20142015,
#   '2014-12-05T00:00:00Z',
#   '02',
#   15,
#   12),
#  (2014020378,
#   '/api/v1/game/2014020378/feed/live',
#   20142015,
#   '2014-12-05T00:30:00Z',
#   '02',
#   1,
#   10),
#  (2014020379,
#   '/api/v1/game/2014020379/feed/live',
#   20142015,
#   '2014-12-05T00:30:00Z',
#   '02',
#   2,
#   9),
#  (2014020380,
#   '/api/v1/game/2014020380/feed/live',
#   20142015,
#   '2014-12-05T00:30:00Z',
#   '02',
#   25,
#   17),
#  (2014020381,
#   '/api/v1/game/2014020381/feed/live',
#   20142015,
#   '2014-12-05T00:30:00Z',
#   '02',
#   7,
#   14),
#  (2014020382,
#   '/api/v1/game/2014020382/feed/live',
#   20142015,
#   '2014-12-05T00:30:00Z',
#   '02',
#   29,
#   13),
#  (2014020383,
#   '/api/v1/game/2014020383/feed/live',
#   20142015,
#   '2014-12-05T01:00:00Z',
#   '02',
#   19,
#   18),
#  (2014020384,
#   '/api/v1/game/2014020384/feed/live',
#   20142015,
#   '2014-12-05T02:00:00Z',
#   '02',
#   21,
#   20),
#  (2014020385,
#   '/api/v1/game/2014020385/feed/live',
#   20142015,
#   '2014-12-05T02:00:00Z',
#   '02',
#   26,
#   53),
#  (2014020386,
#   '/api/v1/game/2014020386/feed/live',
#   20142015,
#   '2014-12-05T03:30:00Z',
#   '02',
#   6,
#   28),
#  (2014020387,
#   '/api/v1/game/2014020387/feed/live',
#   20142015,
#   '2014-12-06T01:00:00Z',
#   '02',
#   24,
#   30),
#  (2014020388,
#   '/api/v1/game/2014020388/feed/live',
#   20142015,
#   '2014-12-06T01:00:00Z',
#   '02',
#   21,
#   52),
#  (2014020389,
#   '/api/v1/game/2014020389/feed/live',
#   20142015,
#   '2014-12-06T01:30:00Z',
#   '02',
#   8,
#   16),
#  (2014020390,
#   '/api/v1/game/2014020390/feed/live',
#   20142015,
#   '2014-12-06T18:00:00Z',
#   '02',
#   9,
#   5),
#  (2014020397,
#   '/api/v1/game/2014020397/feed/live',
#   20142015,
#   '2014-12-06T18:00:00Z',
#   '02',
#   19,
#   2),
#  (2014020391,
#   '/api/v1/game/2014020391/feed/live',
#   20142015,
#   '2014-12-06T21:00:00Z',
#   '02',
#   4,
#   26),
#  (2014020398,
#   '/api/v1/game/2014020398/feed/live',
#   20142015,
#   '2014-12-07T00:00:00Z',
#   '02',
#   16,
#   18),
#  (2014020399,
#   '/api/v1/game/2014020399/feed/live',
#   20142015,
#   '2014-12-07T00:00:00Z',
#   '02',
#   8,
#   25),
#  (2014020392,
#   '/api/v1/game/2014020392/feed/live',
#   20142015,
#   '2014-12-07T00:00:00Z',
#   '02',
#   23,
#   10),
#  (2014020393,
#   '/api/v1/game/2014020393/feed/live',
#   20142015,
#   '2014-12-07T00:00:00Z',
#   '02',
#   3,
#   17),
#  (2014020394,
#   '/api/v1/game/2014020394/feed/live',
#   20142015,
#   '2014-12-07T00:00:00Z',
#   '02',
#   29,
#   14),
#  (2014020395,
#   '/api/v1/game/2014020395/feed/live',
#   20142015,
#   '2014-12-07T00:00:00Z',
#   '02',
#   7,
#   13),
#  (2014020396,
#   '/api/v1/game/2014020396/feed/live',
#   20142015,
#   '2014-12-07T00:00:00Z',
#   '02',
#   15,
#   1),
#  (2014020400,
#   '/api/v1/game/2014020400/feed/live',
#   20142015,
#   '2014-12-07T01:00:00Z',
#   '02',
#   6,
#   53),
#  (2014020401,
#   '/api/v1/game/2014020401/feed/live',
#   20142015,
#   '2014-12-07T03:00:00Z',
#   '02',
#   28,
#   20),
#  (2014020402,
#   '/api/v1/game/2014020402/feed/live',
#   20142015,
#   '2014-12-07T20:00:00Z',
# ...
#   20142015,
#   '2015-02-15T00:00:00Z',
#   '02',
#   29,
#   2),
#  (2014020829,
#   '/api/v1/game/2014020829/feed/live',
#   20142015,
#   '2015-02-15T01:00:00Z',
#   '02',
#   3,
#   53),
#  (2014020827,
#   '/api/v1/game/2014020827/feed/live',
#   20142015,
#   '2015-02-15T01:00:00Z',
#   '02',
#   1,
#   18),
#  (2014020828,
#   '/api/v1/game/2014020828/feed/live',
#   20142015,
#   '2015-02-15T01:00:00Z',
#   '02',
#   12,
#   30),
#  (2014020830,
#   '/api/v1/game/2014020830/feed/live',
#   20142015,
#   '2015-02-15T02:00:00Z',
#   '02',
#   25,
#   21),
#  (2014020832,
#   '/api/v1/game/2014020832/feed/live',
#   20142015,
#   '2015-02-15T03:00:00Z',
#   '02',
#   15,
#   26),
#  (2014020831,
#   '/api/v1/game/2014020831/feed/live',
#   20142015,
#   '2015-02-15T03:00:00Z',
#   '02',
#   23,
#   20),
#  (2014020833,
#   '/api/v1/game/2014020833/feed/live',
#   20142015,
#   '2015-02-15T17:30:00Z',
#   '02',
#   5,
#   16),
#  (2014020834,
#   '/api/v1/game/2014020834/feed/live',
#   20142015,
#   '2015-02-15T22:00:00Z',
#   '02',
#   19,
#   13),
#  (2014020835,
#   '/api/v1/game/2014020835/feed/live',
#   20142015,
#   '2015-02-16T00:30:00Z',
#   '02',
#   4,
#   7),
#  (2014020836,
#   '/api/v1/game/2014020836/feed/live',
#   20142015,
#   '2015-02-16T01:00:00Z',
#   '02',
#   15,
#   24),
#  (2014020837,
#   '/api/v1/game/2014020837/feed/live',
#   20142015,
#   '2015-02-16T01:00:00Z',
#   '02',
#   14,
#   28),
#  (2014020838,
#   '/api/v1/game/2014020838/feed/live',
#   20142015,
#   '2015-02-17T00:00:00Z',
#   '02',
#   3,
#   2),
#  (2014020839,
#   '/api/v1/game/2014020839/feed/live',
#   20142015,
#   '2015-02-17T00:30:00Z',
#   '02',
#   12,
#   9),
#  (2014020840,
#   '/api/v1/game/2014020840/feed/live',
#   20142015,
#   '2015-02-17T00:30:00Z',
#   '02',
#   8,
#   17),
#  (2014020841,
#   '/api/v1/game/2014020841/feed/live',
#   20142015,
#   '2015-02-17T01:00:00Z',
#   '02',
#   22,
#   52),
#  (2014020842,
#   '/api/v1/game/2014020842/feed/live',
#   20142015,
#   '2015-02-17T02:00:00Z',
#   '02',
#   53,
#   21),
#  (2014020843,
#   '/api/v1/game/2014020843/feed/live',
#   20142015,
#   '2015-02-17T02:00:00Z',
#   '02',
#   6,
#   20),
#  (2014020844,
#   '/api/v1/game/2014020844/feed/live',
#   20142015,
#   '2015-02-17T03:00:00Z',
#   '02',
#   30,
#   23),
#  (2014020845,
#   '/api/v1/game/2014020845/feed/live',
#   20142015,
#   '2015-02-17T03:30:00Z',
#   '02',
#   14,
#   26),
#  (2014020847,
#   '/api/v1/game/2014020847/feed/live',
#   20142015,
#   '2015-02-18T00:00:00Z',
#   '02',
#   29,
#   4),
#  (2014020848,
#   '/api/v1/game/2014020848/feed/live',
#   20142015,
#   '2015-02-18T00:00:00Z',
#   '02',
#   15,
#   5),
#  (2014020849,
#   '/api/v1/game/2014020849/feed/live',
#   20142015,
#   '2015-02-18T00:00:00Z',
#   '02',
#   2,
#   12),
#  (2014020846,
#   '/api/v1/game/2014020846/feed/live',
#   20142015,
#   '2015-02-18T00:30:00Z',
#   '02',
#   7,
#   1),
#  (2014020850,
#   '/api/v1/game/2014020850/feed/live',
#   20142015,
#   '2015-02-18T00:30:00Z',
#   '02',
#   13,
#   10),
#  (2014020851,
#   '/api/v1/game/2014020851/feed/live',
#   20142015,
#   '2015-02-18T01:00:00Z',
#   '02',
#   25,
#   19),
#  (2014020852,
#   '/api/v1/game/2014020852/feed/live',
#   20142015,
#   '2015-02-18T01:00:00Z',
#   '02',
#   28,
#   18),
#  (2014020853,
#   '/api/v1/game/2014020853/feed/live',
#   20142015,
#   '2015-02-19T00:00:00Z',
#   '02',
#   8,
#   9),
#  (2014020854,
#   '/api/v1/game/2014020854/feed/live',
#   20142015,
#   '2015-02-19T00:30:00Z',
#   '02',
#   17,
#   16),
#  (2014020855,
#   '/api/v1/game/2014020855/feed/live',
#   20142015,
#   '2015-02-19T02:30:00Z',
#   '02',
#   30,
#   20),
#  (2014020858,
#   '/api/v1/game/2014020858/feed/live',
#   20142015,
#   '2015-02-19T03:00:00Z',
#   '02',
#   14,
#   24),
#  (2014020856,
#   '/api/v1/game/2014020856/feed/live',
#   20142015,
#   '2015-02-19T03:00:00Z',
#   '02',
#   26,
#   21),
#  (2014020857,
#   '/api/v1/game/2014020857/feed/live',
#   20142015,
#   '2015-02-19T03:00:00Z',
#   '02',
#   6,
#   22),
#  (2014020859,
#   '/api/v1/game/2014020859/feed/live',
#   20142015,
#   '2015-02-20T00:00:00Z',
#   '02',
#   18,
#   2),
#  (2014020860,
#   '/api/v1/game/2014020860/feed/live',
#   20142015,
#   '2015-02-20T00:00:00Z',
#   '02',
#   23,
#   3),
#  (2014020861,
#   '/api/v1/game/2014020861/feed/live',
#   20142015,
#   '2015-02-20T00:00:00Z',
#   '02',
#   7,
#   4),
#  (2014020862,
#   '/api/v1/game/2014020862/feed/live',
#   20142015,
#   '2015-02-20T00:00:00Z',
#   '02',
#   29,
#   5),
#  (2014020863,
#   '/api/v1/game/2014020863/feed/live',
#   20142015,
#   '2015-02-20T00:00:00Z',
#   '02',
#   52,
#   15),
#  (2014020864,
#   '/api/v1/game/2014020864/feed/live',
#   20142015,
#   '2015-02-20T00:30:00Z',
#   '02',
#   13,
#   8),
#  (2014020865,
#   '/api/v1/game/2014020865/feed/live',
#   20142015,
#   '2015-02-20T01:30:00Z',
#   '02',
#   28,
#   25),
#  (2014020291,
#   '/api/v1/game/2014020291/feed/live',
#   20142015,
#   '2015-02-21T00:00:00Z',
#   '02',
#   3,
#   7),
#  (2014020867,
#   '/api/v1/game/2014020867/feed/live',
#   20142015,
#   '2015-02-21T00:00:00Z',
#   '02',
#   23,
#   1),
#  (2014020868,
#   '/api/v1/game/2014020868/feed/live',
#   20142015,
#   '2015-02-21T00:00:00Z',
#   '02',
#   10,
#   12),
#  (2014020869,
#   '/api/v1/game/2014020869/feed/live',
#   20142015,
#   '2015-02-21T01:00:00Z',
#   '02',
#   6,
#   19),
#  (2014020870,
#   '/api/v1/game/2014020870/feed/live',
#   20142015,
#   '2015-02-21T01:30:00Z',
#   '02',
#   21,
#   16),
#  (2014020871,
#   '/api/v1/game/2014020871/feed/live',
#   20142015,
#   '2015-02-21T02:00:00Z',
#   '02',
#   24,
#   20),
#  (2014020872,
#   '/api/v1/game/2014020872/feed/live',
#   20142015,
#   '2015-02-21T02:00:00Z',
#   '02',
#   30,
#   22),
#  (2014020873,
#   '/api/v1/game/2014020873/feed/live',
#   20142015,
#   '2015-02-21T17:30:00Z',
#   '02',
#   2,
#   15),
#  (2014020874,
#   '/api/v1/game/2014020874/feed/live',
#   20142015,
#   '2015-02-21T18:00:00Z',
#   '02',
#   18,
#   4),
#  (2014020879,
#   '/api/v1/game/2014020879/feed/live',
#   20142015,
#   '2015-02-22T00:00:00Z',
#   '02',
#   24,
#   22),
#  (2014020875,
#   '/api/v1/game/2014020875/feed/live',
#   20142015,
#   '2015-02-22T00:00:00Z',
#   '02',
#   52,
#   10),
#  (2014020876,
#   '/api/v1/game/2014020876/feed/live',
#   20142015,
#   '2015-02-22T00:00:00Z',
#   '02',
#   29,
#   8),
#  (2014020877,
#   '/api/v1/game/2014020877/feed/live',
#   20142015,
#   '2015-02-22T00:00:00Z',
#   '02',
#   13,
#   9),
#  (2014020878,
#   '/api/v1/game/2014020878/feed/live',
#   20142015,
#   '2015-02-22T00:00:00Z',
#   '02',
#   12,
#   1),
#  (2014020882,
#   '/api/v1/game/2014020882/feed/live',
#   20142015,
#   '2015-02-22T01:00:00Z',
#   '02',
#   14,
#   53),
#  (2014020880,
#   '/api/v1/game/2014020880/feed/live',
#   20142015,
#   '2015-02-22T01:00:00Z',
#   '02',
#   5,
#   19),
#  (2014020881,
#   '/api/v1/game/2014020881/feed/live',
#   20142015,
#   '2015-02-22T01:00:00Z',
#   '02',
#   17,
#   25),
#  (2014020883,
#   '/api/v1/game/2014020883/feed/live',
#   20142015,
#   '2015-02-22T03:00:00Z',
#   '02',
#   26,
#   28),
#  (2014020884,
#   '/api/v1/game/2014020884/feed/live',
#   20142015,
#   '2015-02-22T17:30:00Z',
#   '02',
#   15,
#   4),
#  (2014020885,
#   '/api/v1/game/2014020885/feed/live',
#   20142015,
#   '2015-02-22T20:30:00Z',
#   '02',
#   6,
#   16),
#  (2014020886,
#   '/api/v1/game/2014020886/feed/live',
#   20142015,
#   '2015-02-22T23:00:00Z',
#   '02',
#   18,
#   7),
#  (2014020887,
#   '/api/v1/game/2014020887/feed/live',
#   20142015,
#   '2015-02-22T23:00:00Z',
#   '02',
#   23,
#   2),
#  (2014020888,
#   '/api/v1/game/2014020888/feed/live',
#   20142015,
#   '2015-02-22T23:00:00Z',
#   '02',
#   13,
#   5),
#  (2014020889,
#   '/api/v1/game/2014020889/feed/live',
#   20142015,
#   '2015-02-23T00:00:00Z',
#   '02',
#   14,
#   21),
#  (2014020890,
#   '/api/v1/game/2014020890/feed/live',
#   20142015,
#   '2015-02-23T00:30:00Z',
#   '02',
#   29,
#   3),
#  (2014020891,
#   '/api/v1/game/2014020891/feed/live',
#   20142015,
#   '2015-02-23T01:00:00Z',
#   '02',
#   25,
#   30),
#  (2014020892,
#   '/api/v1/game/2014020892/feed/live',
#   20142015,
#   '2015-02-24T00:00:00Z',
#   '02',
#   53,
#   1),
#  (2014020893,
#   '/api/v1/game/2014020893/feed/live',
#   20142015,
#   '2015-02-24T03:00:00Z',
#   '02',
#   17,
#   24),
#  (2014020894,
#   '/api/v1/game/2014020894/feed/live',
#   20142015,
#   '2015-02-25T00:00:00Z',
#   '02',
#   23,
#   6),
#  (2014020895,
#   '/api/v1/game/2014020895/feed/live',
#   20142015,
#   '2015-02-25T00:00:00Z',
#   '02',
#   53,
#   2),
#  (2014020896,
#   '/api/v1/game/2014020896/feed/live',
#   20142015,
#   '2015-02-25T00:00:00Z',
#   '02',
#   20,
#   3),
#  (2014020897,
#   '/api/v1/game/2014020897/feed/live',
#   20142015,
#   '2015-02-25T00:00:00Z',
#   '02',
#   4,
#   12),
#  (2014020898,
#   '/api/v1/game/2014020898/feed/live',
#   20142015,
#   '2015-02-25T00:00:00Z',
#   '02',
#   7,
#   29),
#  (2014020899,
#   '/api/v1/game/2014020899/feed/live',
#   20142015,
#   '2015-02-25T01:00:00Z',
#   '02',
#   8,
#   19),
#  (2014020900,
#   '/api/v1/game/2014020900/feed/live',
#   20142015,
#   '2015-02-25T01:00:00Z',
#   '02',
#   21,
#   18),
#  (2014020901,
#   '/api/v1/game/2014020901/feed/live',
#   20142015,
#   '2015-02-25T01:00:00Z',
#   '02',
#   22,
#   30),
#  (2014020902,
#   '/api/v1/game/2014020902/feed/live',
#   20142015,
#   '2015-02-25T01:00:00Z',
#   '02',
#   25,
#   52),
#  (2014020903,
#   '/api/v1/game/2014020903/feed/live',
#   20142015,
#   '2015-02-25T01:30:00Z',
#   '02',
#   13,
#   16),
#  (2014020904,
#   '/api/v1/game/2014020904/feed/live',
#   20142015,
#   '2015-02-25T03:30:00Z',
#   '02',
#   17,
#   26),
#  (2014020905,
#   '/api/v1/game/2014020905/feed/live',
#   20142015,
#   '2015-02-26T00:30:00Z',
#   '02',
#   20,
#   1),
#  (2014020906,
#   '/api/v1/game/2014020906/feed/live',
#   20142015,
#   '2015-02-26T01:00:00Z',
#   '02',
#   5,
#   15),
#  (2014020907,
#   '/api/v1/game/2014020907/feed/live',
#   20142015,
#   '2015-02-26T03:00:00Z',
#   '02',
#   9,
#   24),
#  (2014020908,
#   '/api/v1/game/2014020908/feed/live',
#   20142015,
#   '2015-02-27T00:00:00Z',
#   '02',
#   23,
#   7),
#  (2014020909,
#   '/api/v1/game/2014020909/feed/live',
#   20142015,
#   '2015-02-27T00:00:00Z',
#   '02',
#   53,
#   3),
#  (2014020910,
#   '/api/v1/game/2014020910/feed/live',
#   20142015,
#   '2015-02-27T00:00:00Z',
#   '02',
#   8,
#   29),
#  (2014020911,
#   '/api/v1/game/2014020911/feed/live',
#   20142015,
#   '2015-02-27T00:30:00Z',
#   '02',
#   4,
#   10),
#  (2014020912,
#   '/api/v1/game/2014020912/feed/live',
#   20142015,
#   '2015-02-27T00:30:00Z',
#   '02',
#   16,
#   13),
#  (2014020914,
#   '/api/v1/game/2014020914/feed/live',
#   20142015,
#   '2015-02-27T01:00:00Z',
#   '02',
#   19,
#   52),
#  (2014020913,
#   '/api/v1/game/2014020913/feed/live',
#   20142015,
#   '2015-02-27T01:30:00Z',
#   '02',
#   30,
#   18),
#  (2014020915,
#   '/api/v1/game/2014020915/feed/live',
#   20142015,
#   '2015-02-27T03:30:00Z',
#   '02',
#   9,
#   26),
#  (2014020916,
#   '/api/v1/game/2014020916/feed/live',
#   20142015,
#   '2015-02-27T03:30:00Z',
#   '02',
#   17,
#   28),
#  (2014020917,
#   '/api/v1/game/2014020917/feed/live',
#   20142015,
#   '2015-02-28T00:00:00Z',
#   '02',
#   6,
#   1),
#  (2014020918,
#   '/api/v1/game/2014020918/feed/live',
#   20142015,
#   '2015-02-28T00:00:00Z',
#   '02',
#   20,
#   2),
#  (2014020919,
#   '/api/v1/game/2014020919/feed/live',
#   20142015,
#   '2015-02-28T00:00:00Z',
#   '02',
#   15,
#   12),
#  (2014020920,
#   '/api/v1/game/2014020920/feed/live',
#   20142015,
#   '2015-02-28T00:30:00Z',
#   '02',
#   16,
#   14),
#  (2014020921,
#   '/api/v1/game/2014020921/feed/live',
#   20142015,
#   '2015-02-28T01:30:00Z',
#   '02',
#   21,
#   25),
#  (2014020922,
#   '/api/v1/game/2014020922/feed/live',
#   20142015,
#   '2015-02-28T03:00:00Z',
#   '02',
#   26,
#   24),
#  (2014020924,
#   '/api/v1/game/2014020924/feed/live',
#   20142015,
#   '2015-02-28T20:00:00Z',
#   '02',
#   17,
#   18),
#  (2014020923,
#   '/api/v1/game/2014020923/feed/live',
#   20142015,
#   '2015-02-28T20:00:00Z',
#   '02',
#   7,
#   13),
#  (2014020925,
#   '/api/v1/game/2014020925/feed/live',
#   20142015,
#   '2015-02-28T22:00:00Z',
#   '02',
#   12,
#   2),
#  (2014020926,
#   '/api/v1/game/2014020926/feed/live',
#   20142015,
#   '2015-02-28T22:00:00Z',
#   '02',
#   1,
#   29),
#  (2014020927,
#   '/api/v1/game/2014020927/feed/live',
#   20142015,
#   '2015-02-28T22:30:00Z',
#   '02',
#   53,
#   6),
#  (2014020928,
#   '/api/v1/game/2014020928/feed/live',
#   20142015,
#   '2015-03-01T00:00:00Z',
#   '02',
#   10,
#   8),
#  (2014020929,
#   '/api/v1/game/2014020929/feed/live',
#   20142015,
#   '2015-03-01T01:00:00Z',
#   '02',
#   3,
#   4),
#  (2014020932,
#   '/api/v1/game/2014020932/feed/live',
#   20142015,
#   '2015-03-01T03:00:00Z',
#   '02',
#   9,
#   28),
#  (2014020930,
#   '/api/v1/game/2014020930/feed/live',
#   20142015,
#   '2015-03-01T03:00:00Z',
#   '02',
#   30,
#   21),
#  (2014020931,
#   '/api/v1/game/2014020931/feed/live',
#   20142015,
#   '2015-03-01T03:00:00Z',
#   '02',
#   19,
#   22),
#  (2014020933,
#   '/api/v1/game/2014020933/feed/live',
#   20142015,
#   '2015-03-01T21:00:00Z',
#   '02',
#   26,
#   52),
#  (2014020934,
#   '/api/v1/game/2014020934/feed/live',
#   20142015,
#   '2015-03-01T22:00:00Z',
#   '02',
#   14,
#   13),
#  (2014020935,
#   '/api/v1/game/2014020935/feed/live',
#   20142015,
#   '2015-03-01T22:00:00Z',
#   '02',
#   29,
#   5),
#  (2014020936,
#   '/api/v1/game/2014020936/feed/live',
#   20142015,
#   '2015-03-02T00:00:00Z',
#   '02',
#   10,
#   15),
#  (2014020937,
#   '/api/v1/game/2014020937/feed/live',
#   20142015,
#   '2015-03-02T01:00:00Z',
#   '02',
#   24,
#   25),
#  (2014020938,
#   '/api/v1/game/2014020938/feed/live',
#   20142015,
#   '2015-03-02T02:30:00Z',
#   '02',
#   19,
#   23),
#  (2014020939,
#   '/api/v1/game/2014020939/feed/live',
#   20142015,
#   '2015-03-03T00:00:00Z',
#   '02',
#   18,
#   3),
#  (2014020940,
#   '/api/v1/game/2014020940/feed/live',
#   20142015,
#   '2015-03-03T01:30:00Z',
#   '02',
#   12,
#   16),
#  (2014020941,
#   '/api/v1/game/2014020941/feed/live',
#   20142015,
#   '2015-03-03T03:00:00Z',
#   '02',
#   8,
#   28),
#  (2014020942,
#   '/api/v1/game/2014020942/feed/live',
#   20142015,
#   '2015-03-04T00:00:00Z',
#   '02',
#   18,
#   1),
#  (2014020943,
#   '/api/v1/game/2014020943/feed/live',
#   20142015,
#   '2015-03-04T00:00:00Z',
#   '02',
#   20,
#   4),
#  (2014020944,
#   '/api/v1/game/2014020944/feed/live',
#   20142015,
#   '2015-03-04T00:00:00Z',
#   '02',
#   15,
#   29),
#  (2014020945,
#   '/api/v1/game/2014020945/feed/live',
#   20142015,
#   '2015-03-04T00:30:00Z',
#   '02',
#   7,
#   14),
#  (2014020946,
#   '/api/v1/game/2014020946/feed/live',
#   20142015,
#   '2015-03-04T00:30:00Z',
#   '02',
#   10,
#   13),
#  (2014020947,
#   '/api/v1/game/2014020947/feed/live',
#   20142015,
#   '2015-03-04T01:00:00Z',
#   '02',
#   9,
#   30),
#  (2014020948,
#   '/api/v1/game/2014020948/feed/live',
#   20142015,
#   '2015-03-04T01:30:00Z',
#   '02',
#   2,
#   25),
#  (2014020949,
#   '/api/v1/game/2014020949/feed/live',
#   20142015,
#   '2015-03-04T02:00:00Z',
#   '02',
#   24,
#   53),
#  (2014020950,
#   '/api/v1/game/2014020950/feed/live',
#   20142015,
#   '2015-03-04T02:30:00Z',
#   '02',
#   26,
#   22),
#  (2014020951,
#   '/api/v1/game/2014020951/feed/live',
#   20142015,
#   '2015-03-04T03:00:00Z',
#   '02',
#   28,
#   23),
#  (2014020952,
#   '/api/v1/game/2014020952/feed/live',
#   20142015,
#   '2015-03-05T00:30:00Z',
#   '02',
#   9,
#   52),
#  (2014020953,
#   '/api/v1/game/2014020953/feed/live',
#   20142015,
#   '2015-03-05T01:00:00Z',
#   '02',
#   3,
#   17),
#  (2014020955,
#   '/api/v1/game/2014020955/feed/live',
#   20142015,
#   '2015-03-05T03:00:00Z',
#   '02',
#   8,
#   24),
#  (2014020954,
#   '/api/v1/game/2014020954/feed/live',
#   20142015,
#   '2015-03-05T03:00:00Z',
#   '02',
#   5,
#   21),
#  (2014020956,
#   '/api/v1/game/2014020956/feed/live',
#   20142015,
#   '2015-03-06T00:00:00Z',
#   '02',
#   20,
#   6),
#  (2014020957,
#   '/api/v1/game/2014020957/feed/live',
#   20142015,
#   '2015-03-06T00:00:00Z',
#   '02',
#   19,
#   4),
#  (2014020958,
#   '/api/v1/game/2014020958/feed/live',
#   20142015,
#   '2015-03-06T00:00:00Z',
#   '02',
#   30,
#   15),
#  (2014020959,
#   '/api/v1/game/2014020959/feed/live',
#   20142015,
#   '2015-03-06T00:30:00Z',
#   '02',
#   10,
#   14),
#  (2014020960,
#   '/api/v1/game/2014020960/feed/live',
#   20142015,
#   '2015-03-06T00:30:00Z',
#   '02',
#   25,
#   13),
#  (2014020961,
#   '/api/v1/game/2014020961/feed/live',
#   20142015,
#   '2015-03-06T01:00:00Z',
#   '02',
#   2,
#   18),
#  (2014020962,
#   '/api/v1/game/2014020962/feed/live',
#   20142015,
#   '2015-03-06T02:00:00Z',
#   '02',
#   23,
#   53),
#  (2014020963,
#   '/api/v1/game/2014020963/feed/live',
#   20142015,
#   '2015-03-06T03:30:00Z',
#   '02',
#   8,
#   26),
#  (2014020964,
#   '/api/v1/game/2014020964/feed/live',
#   20142015,
#   '2015-03-07T00:00:00Z',
#   '02',
#   29,
#   1),
#  (2014020965,
#   '/api/v1/game/2014020965/feed/live',
#   20142015,
#   '2015-03-07T00:00:00Z',
#   '02',
#   30,
#   12),
#  (2014020966,
#   '/api/v1/game/2014020966/feed/live',
#   20142015,
#   '2015-03-07T00:30:00Z',
#   '02',
#   7,
#   9),
#  (2014020967,
#   '/api/v1/game/2014020967/feed/live',
#   20142015,
#   '2015-03-07T00:30:00Z',
#   '02',
#   20,
#   17),
#  (2014020968,
#   '/api/v1/game/2014020968/feed/live',
#   20142015,
#   '2015-03-07T01:30:00Z',
#   '02',
#   22,
#   16),
#  (2014020969,
#   '/api/v1/game/2014020969/feed/live',
#   20142015,
#   '2015-03-07T03:00:00Z',
#   '02',
#   5,
#   24),
#  ...]
